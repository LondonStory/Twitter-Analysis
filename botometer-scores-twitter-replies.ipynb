# %% [markdown]
# ## This notebook uses [Botometer](https://github.com/IUNetSci/botometer-python) for investigating a list of Twitter accounts

# %% [markdown]
# ### Installs and imports

# %%
# !pip install botometer requests tweepy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: botometer in /usr/local/lib/python3.7/dist-packages (1.6.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (2.23.0)
# Requirement already satisfied: tweepy in /usr/local/lib/python3.7/dist-packages (3.10.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from tweepy) (1.15.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tweepy) (1.3.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->tweepy) (3.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests) (2022.9.24)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests) (1.24.3)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.7/dist-packages (from requests) (1.7.1)

# %%
import botometer
import pandas as pd

# %% [markdown]
# ### Declare API keys

# %%
rapidapi_key = "XXYYYZ"

twitter_app_auth = {
    'consumer_key': 'XXYZZ',
    'consumer_secret': 'XXYYZZ',
    'access_token': 'XXYYZZ',
    'access_token_secret': 'XXYYZZ',
  }

# %% [markdown]
# ### Define a `Botometer` API call request

# %%
bom = botometer.Botometer(wait_on_ratelimit=True,
                          rapidapi_key=rapidapi_key,
                          **twitter_app_auth)

# %% [markdown]
# ### Define functions to extract and print different scores

# %% [markdown]
# Extract specific scores

# %%
def extract_scores (result):
  return [result['cap']['english'], 
          result['cap']['universal'], 
          result['raw_scores']['english']['overall'], 
          result['raw_scores']['universal']['overall'], 
          result['display_scores']['english']['overall'], 
          result['display_scores']['universal']['overall']]

# %% [markdown]
# Print scores

# %%
def print_scores (result):
  print ("--- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---")
  print ("Cap in English:", result['cap']['english'])
  print ("Cap in Universal:", result['cap']['universal'])

  print ("--- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---")
  print ("Overall raw score in English:", result['raw_scores']['english']['overall'])
  print ("Overall raw score in Universal:", result['raw_scores']['universal']['overall'])

  print ("--- Display scores: same as raw scores, but in the [0,5] range ---")
  print ("Overall display score in English:", result['display_scores']['english']['overall'])
  print ("Overall display score in Universal:", result['display_scores']['universal']['overall'])

# %% [markdown]
# ### Test on an account

# %% [markdown]
# **Meanings of the elements in the response**
#
# * `user`: Twitter user object (from the user) plus the language inferred from majority of tweets
#
# * `raw scores`: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features; in each case we have the overall score and the sub-scores for each bot class (see below for subclass names and definitions)
#
# * `display scores`: same as raw scores, but in the [0,5] range
#
# * `cap`: conditional probability that accounts with a score equal to or greater than this are automated; based on inferred language
#
# **Meanings of the bot type scores**
#
# * `fake_follower`: bots purchased to increase follower counts
#
# * `self_declared`: bots from botwiki.org
#
# * `astroturf`: manually labeled political bots and accounts involved in follow trains that systematically delete content
#
# * `spammer`: accounts labeled as spambots from several datasets
#
# * `financial`: bots that post using cashtags
#
# * `other`: miscellaneous other bots obtained from manual annotation, user feedback, etc.

# %%
result = bom.check_account('narendramodi')
#print (result)
print (extract_scores (result))
print_scores(result)
# Out:
# [0.793087009461318, 0.8053787930995948, 0.38, 0.5, 1.9, 2.5]
# --- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---
# Cap in English: 0.793087009461318
# Cap in Universal: 0.8053787930995948
# --- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---
# Overall raw score in English: 0.38
# Overall raw score in Universal: 0.5
# --- Display scores: same as raw scores, but in the [0,5] range ---
# Overall display score in English: 1.9
# Overall display score in Universal: 2.5

# %% [markdown]
# ### Load the dataset of Tweet replies

# %% [markdown]
# Mount drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Load the dataframe

# %%
#df = pd.read_csv ('/content/drive/MyDrive/replies-alviinaalametsa-annotated.csv')
df = pd.read_csv ('/content/drive/MyDrive/replies-larrouturou-annotated.csv')

# %% [markdown]
# Check the shape of the pandas dataframe

# %%
#df.shape
df.columns
# Out:
# Index(['id', 'conversation_id', 'created_at', 'date', 'timezone', 'place',
#        'tweet', 'language', 'hashtags', 'cashtags', 'user_id', 'user_id_str',
#        'username', 'name', 'day', 'hour', 'link', 'urls', 'photos', 'video',
#        'thumbnail', 'retweet', 'nlikes', 'nreplies', 'nretweets', 'quote_url',
#        'search', 'near', 'geo', 'source', 'user_rt_id', 'user_rt',
#        'retweet_id', 'reply_to', 'retweet_date', 'translate', 'trans_src',
#        'trans_dest', 'sentiment', 'annotator', 'annotation_id', 'updated_at',
#        'lead_time'],
#       dtype='object')

# %%
df.head(5)
# Out:
#       id      conversation_id                   created_at  \
# 0  31706  1541498855061164034  2022-10-09T19:11:18.210103Z
# 1  31705  1541498855061164034  2022-10-09T19:10:49.199776Z
# 2  31704  1541498855061164034  2022-10-09T19:10:39.108231Z
# 3  31703  1541498855061164034  2022-10-09T19:10:29.229150Z
# 4  31702  1541498855061164034  2022-10-09T19:10:14.808636Z
#
#                   date  timezone  place  \
# 0  2022-07-01 10:56:03       200    NaN
# 1  2022-06-27 21:10:48       200    NaN
# 2  2022-06-27 21:42:24       200    NaN
# 3  2022-06-27 21:50:02       200    NaN
# 4  2022-06-27 21:50:41       200    NaN
#
#                                                tweet language  \
# 0  @larrouturou @zoo_bear @AltNews @PMOIndia @Ind...       en
# 1  @larrouturou @zoo_bear @AltNews @PMOIndia @Ind...      qam
# 2  @larrouturou @zoo_bear @AltNews @PMOIndia @Ind...      qme
# 3  @larrouturou @zoo_bear @AltNews @PMOIndia @Ind...       en
# 4  @larrouturou @zoo_bear @AltNews @PMOIndia @Ind...       en
#
#                                             hashtags cashtags  ...  \
# 0                                                 []       []  ...
# 1                                                 []       []  ...
# 2              ['istandwithzubair', 'releasezubair']       []  ...
# 3  ['bjp', 'istandwithzubair', 'standwithteestase...       []  ...
# 4                                                 []       []  ...
#
#                                             reply_to  retweet_date translate  \
# 0  [{'screen_name': 'larrouturou', 'name': 'Pierr...           NaN       NaN
# 1  [{'screen_name': 'larrouturou', 'name': 'Pierr...           NaN       NaN
# 2  [{'screen_name': 'larrouturou', 'name': 'Pierr...           NaN       NaN
# 3  [{'screen_name': 'larrouturou', 'name': 'Pierr...           NaN       NaN
# 4  [{'screen_name': 'larrouturou', 'name': 'Pierr...           NaN       NaN
#
#   trans_src  trans_dest                                          sentiment  \
# 0       NaN         NaN                                             Favour
# 1       NaN         NaN                                    unrecoganisable
# 2       NaN         NaN                                             Favour
# 3       NaN         NaN                                             Favour
# 4       NaN         NaN  Questioning stature of the speaker (not widely...
#
#   annotator annotation_id                   updated_at  lead_time
# 0         2           281  2022-10-09T19:11:18.210132Z     25.844
# 1         2           280  2022-10-09T19:10:49.199805Z      8.488
# 2         2           279  2022-10-09T19:10:39.108261Z      6.661
# 3         2           278  2022-10-09T19:10:29.229179Z     12.636
# 4         2           277  2022-10-09T19:10:14.808675Z      9.150
#
# [5 rows x 43 columns]

# %% [markdown]
# ### Scrape all usernames

# %%
username_list = df ['username'].tolist()
print (len(username_list))
# Out:
# 171

# %% [markdown]
# Print the list of usernames

# %%
print (username_list)
# Out:
# ['Nmenon777', 'AteequeKLD', 'CoolHugs_', 'ICIMonline', 'mudde_rama', 'MuhammadXunaid0', 'shahruk92461711', 'abdullahsir36', 'Kaavi2021', 'CHILLPI25037592', 'ProudIndian_253', 'Hashimalhanfi', 'KMortha', 'ProudIndian_253', 'chandrats06', 'lemonchusleee', 'zubair7409', 'Md35556134', 'Sreedha24324771', 'Iamraje78412219', 'Shaikhm04230983', 'cricketspr', 'yaji63', 'mrImteyaz8', 'SkSuhael', 'ehram123', '_irrationality0', 'tradingfutures1', 'SankarsanBarik4', 'TarunKGupta2', 'canarayan1', 'KiranKumarGK1', 'Avijit3k2', 'ramanvk819', 'Pj_Keshriyagrp', 'JaiPoori', 'aamehta1980', 'Subash37006856', 'underpaidsevak', 'Manishis050', 'NikhilRaod', 'asifmohd63', 'ra54077891', 'rajarshi_sg', 'MaskMan17122213', 'Notsoyoung5', 'Sid95879', 'anbokshi', 'dryahyakazi', 'shanthala_kumar', 'Shweta_India', 'Srikarch11', 'dinakar24', 'Namami_Ganga', 'Lisali89880277', 'funnyface234', 'wind_duo', 'nayakSSekhar', 'tuubol', 'Sanju40382206', 'Udays73', 'Lakshmoji', 'ReddyR2D2', 'ranveer2252', 'nimminavya', 'rajesh104', 'lonerangerin', 'ashwinpshenoy', 'BabuRao_Deva', 'HimalayasOuter', 'kewal_negi', 'mvmm12', 'Virampampaniya4', 'anshsem', 'shradesai', 'Phoenix_on_Rise', 'sain_me_', 'SHIVACINE16', 'sarcasticSoda', 'IamSuperEminent', 'ThawaniBhushan', 'sanghi_engineer', 'lawmaverick1', 'lawmaverick1', 'papa_nasham', 'omprakash2711', 'an_unknown_wish', 'itsflanker', 'Nnkk44656557', 'icekoolrahul', 'DipayanDMR', 'Akk_anand', 'Annanyabanerje7', 'Evils_Paradise', 'Bdjena988', 'santuriju', 'thejendra', 'Prasenjit97m', 'Prasenjit97m', 'zab_khan92', 'Aishwaryarbagla', 'Sreedha24324771', 'ashwinpshenoy', 'jainarahari108', 'Akk_anand', 'Annanyabanerje7', 'AtulTheKaushal', 'IndiaSolNW', 'mvmm12', 'papa_nasham', 'sarcasticSoda', 'jainarahari108', 'maverick9762', 'nkagr2706', 'vjv02', 'SamsulH40825884', 'SamsulH40825884', 'KumarPangolin', 'OC_Gaaji', 'AnisurrahamanN2', 'thewarriorbro', 'FaridAnsari0786', 'FaridAnsari0786', 'hhmollick', 'bitmasti', 'AtulTheKaushal', 'IndiaSolNW', 'ranveer2252', 'nimminavya', 'rajesh104', 'lonerangerin', 'BabuRao_Deva', 'HimalayasOuter', 'kewal_negi', 'Virampampaniya4', 'anshsem', 'shradesai', 'Phoenix_on_Rise', 'sain_me_', 'SHIVACINE16', 'TheWhiteWaIker', 'ThawaniBhushan', 'sanghi_engineer', 'lawmaverick1', 'lawmaverick1', 'omprakash2711', 'an_unknown_wish', 'itsflanker', 'Nnkk44656557', 'icekoolrahul', 'DipayanDMR', 'Evils_Paradise', 'Bdjena988', 'santuriju', 'thejendra', 'Prasenjit97m', 'Prasenjit97m', 'zab_khan92', 'Aishwaryarbagla', 'Sreedha24324771', 'maverick9762', 'frankblunt2021', 'nkagr2706', 'vjv02', 'SamsulH40825884', 'SamsulH40825884', 'KumarPangolin', 'hhmollick', 'FaridAnsari0786', 'FaridAnsari0786', 'bitmasti']

# %% [markdown]
# ### Run Botometer over the list of accounts

# %% [markdown]
# Run through the list of accounts and print output on shell

# %%
for account_name, result in bom.check_accounts_in (username_list):
  print ("=======================", account_name, "=======================")
  print (result)
# Out:
# ======================= Nmenon777 =======================
# {'cap': {'english': 0.3912159239072283, 'universal': 0.37678996390568303}, 'display_scores': {'english': {'astroturf': 1.3, 'fake_follower': 0.3, 'financial': 0.1, 'other': 1.4, 'overall': 0.4, 'self_declared': 0.1, 'spammer': 0.0}, 'universal': {'astroturf': 1.8, 'fake_follower': 0.4, 'financial': 0.1, 'other': 1.2, 'overall': 0.3, 'self_declared': 0.0, 'spammer': 0.0}}, 'raw_scores': {'english': {'astroturf': 0.26, 'fake_follower': 0.06, 'financial': 0.02, 'other': 0.28, 'overall': 0.07, 'self_declared': 0.02, 'spammer': 0.0}, 'universal': {'astroturf': 0.35, 'fake_follower': 0.08, 'financial': 0.02, 'other': 0.24, 'overall': 0.06, 'self_declared': 0.0, 'spammer': 0.01}}, 'user': {'majority_lang': 'en', 'user_data': {'id_str': '799998182209961984', 'screen_name': 'Nmenon777'}}}
# ======================= AteequeKLD =======================
# {'cap': {'english': 0.8395863545645614, 'universal': 0.8054092120440788}, 'display_scores': {'english': {'astroturf': 0.4, 'fake_follower': 1.8, 'financial': 1.6, 'other': 4.3, 'overall': 4.3, 'self_declared': 0.1, 'spammer': 0.2}, 'universal': {'astroturf': 0.5, 'fake_follower': 1.9, 'financial': 1.6, 'other': 3.3, 'overall': 3.3, 'self_declared': 0.6, 'spammer': 0.1}}, 'raw_scores': {'english': {'astroturf': 0.09, 'fake_follower': 0.35, 'financial': 0.32, 'other': 0.86, 'overall': 0.86, 'self_declared': 0.02, 'spammer': 0.05}, 'universal': {'astroturf': 0.1, 'fake_follower': 0.38, 'financial': 0.32, 'other': 0.66, 'overall': 0.66, 'self_declared': 0.13, 'spammer': 0.02}}, 'user': {'majority_lang': 'hi', 'user_data': {'id_str': '861103605675327490', 'screen_name': 'AteequeKLD'}}}
# ======================= CoolHugs_ =======================
# {'cap': {'english': 0.7852210697594887, 'universal': 0.7089830786080018}, 'display_scores': {'english': {'astroturf': 1.1, 'fake_follower': 1.2, 'financial': 0.6, 'other': 2.0, 'overall': 1.6, 'self_declared': 0.0, 'spammer': 0.1}, 'universal': {'astroturf': 1.5, 'fake_follower': 0.4, 'financial': 0.2, 'other': 1.4, 'overall': 1.0, 'self_declared': 0.0, 'spammer': 0.0}}, 'raw_scores': {'english': {'astroturf': 0.22, 'fake_follower': 0.23, 'financial': 0.12, 'other': 0.41, 'overall': 0.33, 'self_declared': 0.0, 'spammer': 0.02}, 'universal': {'astroturf': 0.3, 'fake_follower': 0.07, 'financial': 0.04, 'other': 0.28, 'overall': 0.2, 'self_declared': 0.0, 'spammer': 0.0}}, 'user': {'majority_lang': 'en', 'user_data': {'id_str': '79280418', 'screen_name': 'CoolHugs_'}}}
# ======================= ICIMonline =======================
# {'cap': {'english': 0.7965971518887632, 'universal': 0.8054123562973726}, 'display_scores': {'english': {'astroturf': 1.8, 'fake_follower': 2.2, 'financial': 2.1, 'other': 3.2, 'overall': 3.2, 'self_declared': 0.2, 'spammer': 0.2}, 'universal': {'astroturf': 1.0, 'fake_follower': 1.8, 'financial': 1.5, 'other': 2.6, 'overall': 2.6, 'self_declared': 0.0, 'spammer': 0.2}}, 'raw_scores': {'english': {'astroturf': 0.36, 'fake_follower': 0.45, 'financial': 0.42, 'other': 0.63, 'overall': 0.63, 'self_declared': 0.04, 'spammer': 0.05}, 'universal': {'astroturf': 0.21, 'fake_follower': 0.37, 'financial': 0.3, 'other': 0.51, 'overall': 0.51, 'self_declared': 0.0, 'spammer': 0.05}}, 'user': {'majority_lang': 'en', 'user_data': {'id_str': '1384891302534336515', 'screen_name': 'ICIMonline'}}}
# ======================= mudde_rama =======================
# {'cap': {'english': 0.659646495284545, 'universal': 0.43650814830094437}, 'display_scores': {'english': {'astroturf': 0.4, 'fake_follower': 0.4, 'financial': 0.2, 'other': 0.7, 'overall': 0.9, 'self_declared': 0.0, 'spammer': 0.0}, 'universal': {'astroturf': 0.6, 'fake_follower': 0.6, 'financial': 0.0, 'other': 1.0, 'overall': 0.4, 'self_declared': 0.1, 'spammer': 0.2}}, 'raw_scores': {'english': {'astroturf': 0.08, 'fake_follower': 0.09, 'financial': 0.03, 'other': 0.14, 'overall': 0.18, 'self_declared': 0.0, 'spammer': 0.01}, 'universal': {'astroturf': 0.13, 'fake_follower': 0.13, 'financial': 0.01, 'other': 0.21, 'overall': 0.08, 'self_declared': 0.02, 'spammer': 0.05}}, 'user': {'majority_lang': 'en', 'user_data': {'id_str': '723542106451546112', 'screen_name': 'mudde_rama'}}}
# ======================= MuhammadXunaid0 =======================
# {'cap': {'english': 0.7611878625273879, 'universal': 0.5488888157824968}, 'display_scores': {'english': {'astroturf': 0.6, 'fake_follower': 0.1, 'financial': 0.7, 'other': 2.6, 'overall': 1.4, 'self_declared': 0.0, 'spammer': 0.0}, 'universal': {'astroturf': 0.4, 'fake_follower': 0.2, 'financial': 0.4, 'other': 1.7, 'overall': 0.6, 'self_declared': 0.0, 'spammer': 0.0}}, 'raw_scores': {'english': {'astroturf': 0.13, 'fake_follower': 0.02, 'financial': 0.14, 'other': 0.51, 'overall': 0.27, 'self_declared': 0.0, 'spammer': 0.01}, 'universal': {'astroturf': 0.07, 'fake_follower': 0.04, 'financial': 0.07, 'other': 0.34, 'overall': 0.12, 'self_declared': 0.0, 'spammer': 0.0}}, 'user': {'majority_lang': 'en', 'user_data': {'id_str': '1143910538797297666', 'screen_name': 'MuhammadXunaid0'}}}
# ======================= shahruk92461711 =======================
# {'cap': {'english': 0.8748575042966269, 'universal': 0.8082278383974655}, 'display_scores': {'english': {'astroturf': 0.4, 'fake_follower': 3.6, 'financial': 0.4, 'other': 4.6, 'overall': 4.6, 'self_declared': 2.2, 'spammer': 1.8}, 'universal': {'astroturf': 0.2, 'fake_follower': 3.6, 'financial': 0.7, 'other': 3.4, 'overall': 3.6, 'self_declared': 1.9, 'spammer': 1.0}}, 'raw_scores': {'english': {'astroturf': 0.07, 'fake_follower': 0.71, 'financial': 0.08, 'other': 0.91, 'overall': 0.91, 'self_declared': 0.43, 'spammer': 0.37}, 'universal': {'astroturf': 0.03, 'fake_follower': 0.73, 'financial': 0.14, 'other': 0.67, 'overall': 0.73, 'self_declared': 0.38, 'spammer': 0.21}}, 'user': {'majority_lang': 'qme', 'user_data': {'id_str': '1472119098775683072', 'screen_name': 'shahruk92461711'}}}
# ======================= abdullahsir36 =======================
# {'cap': {'english': 0.6915799517497913, 'universal': 0.4658392474232361}, 'display_scores': {'english': {'astroturf': 0.3, 'fake_follower': 0.6, 'financial': 0.6, 'other': 1.8, 'overall': 1.0, 'self_declared': 0.0, 'spammer': 0.0}, 'universal': {'astroturf': 0.3, 'fake_follower': 0.0, 'financial': 0.2, 'other': 0.8, 'overall': 0.4, 'self_declared': 0.0, 'spammer': 0.0}}, 'raw_scores': {'english': {'astroturf': 0.06, 'fake_follower': 0.11, 'financial': 0.12, 'other': 0.37, 'overall': 0.2, 'self_declared': 0.0, 'spammer': 0.01}, 'universal': {'astroturf': 0.06, 'fake_follower': 0.0, 'financial': 0.04, 'other': 0.17, 'overall': 0.09, 'self_declared': 0.0, 'spammer': 0.0}}, 'user': {'majority_lang': 'en', 'user_data': {'id_str': '2721843344', 'screen_name': 'abdullahsir36'}}}
# ======================= Kaavi2021 =======================
# {'cap': {'english': 0.7546218700467833, 'universal': 0.8030212452554465}, 'display_scores': {'english': {'astroturf': 2.2, 'fake_follower': 1.2, 'financial': 0.0, 'other': 2.0, 'overall': 1.3, 'self_declared': 0.1, 'spammer': 0.0}, 'universal': {'astroturf': 2.5, 'fake_follower': 1.2, 'financial': 0.0, 'other': 2.4, 'overall': 2.0, 'self_declared': 0.0, 'spammer': 0.0}}, 'raw_scores': {'english': {'astroturf': 0.44, 'fake_follower': 0.24, 'financial': 0.0, 'other': 0.41, 'overall': 0.26, 'self_declared': 0.02, 'spammer': 0.01}, 'universal': {'astroturf': 0.5, 'fake_follower': 0.25, 'financial': 0.0, 'other': 0.49, 'overall': 0.4, 'self_declared': 0.0, 'spammer': 0.01}}, 'user': {'majority_lang': 'en', 'user_data': {'id_str': '1113946270303969280', 'screen_name': 'Kaavi2021'}}}
# ======================= CHILLPI25037592 =======================
# {'cap': {'english': 0.7920317685697057, 'universal': 0.7828265255249504}, 'display_scores': {'english': {'astroturf': 0.6, 'fake_follower': 0.9, 'financial': 0.2, 'other': 2.0, 'overall': 1.8, 'self_declared': 0.0, 'spammer': 0.4}, 'universal': {'astroturf': 0.6, 'fake_follower': 0.6, 'financial': 0.2, 'other': 1.2, 'overall': 1.4, 'self_declared': 0.0, 'spammer': 0.4}}, 'raw_scores': {'english': {'astroturf': 0.12, 'fake_follower': 0.18, 'financial': 0.05, 'other': 0.39, 'overall': 0.37, 'self_declared': 0.0, 'spammer': 0.07}, 'universal': {'astroturf': 0.13, 'fake_follower': 0.11, 'financial': 0.04, 'other': 0.24, 'overall': 0.29, 'self_declared': 0.01, 'spammer': 0.08}}, 'user': {'majority_lang': 'hi', 'user_data': {'id_str': '1434201266188689408', 'screen_name': 'CHILLPI25037592'}}}
# ======================= ProudIndian_253 =======================
# {'cap': {'english': 0.7470839770895665, 'universal': 0.7784494983408411}, 'display_scores': {'english': {'astroturf': 0.7, 'fake_follower': 0.6, 'financial': 0.0, 'other': 2.2, 'overall': 1.2, 'self_declared': 0.0, 'spammer': 0.4}, 'universal': {'astroturf': 1.0, 'fake_follower': 0.4, 'financial': 0.0, 'other': 1.2, 'overall': 1.4, 'self_declared': 0.0, 'spammer': 0.2}}, 'raw_scores': {'english': {'astroturf': 0.14, 'fake_follower': 0.11, 'financial': 0.0, 'other': 0.44, 'overall': 0.25, 'self_declared': 0.01, 'spammer': 0.09}, 'universal': {'astroturf': 0.2, 'fake_follower': 0.08, 'financial': 0.0, 'other': 0.23, 'overall': 0.28, 'self_declared': 0.01, 'spammer': 0.05}}, 'user': {'majority_lang': 'en', 'user_data': {'id_str': '1449071721768620036', 'screen_name': 'ProudIndian_253'}}}
# ======================= Hashimalhanfi =======================
# {'cap': {'english': 0.7969290189014606, 'universal': 0.7897432630001835}, 'display_scores': {'english': {'astroturf': 0.6, 'fake_follower': 0.6, 'financial': 0.0, 'other': 2.8, 'overall': 2.8, 'self_declared': 0.2, 'spammer': 0.7}, 'universal': {'astroturf': 0.8, 'fake_follower': 0.9, 'financial': 0.1, 'other': 1.6, 'overall': 1.6, 'self_declared': 0.2, 'spammer': 0.4}}, 'raw_scores': {'english': {'astroturf': 0.11, 'fake_follower': 0.12, 'financial': 0.01, 'other': 0.57, 'overall': 0.57, 'self_declared': 0.03, 'spammer': 0.14}, 'universal': {'astroturf': 0.15, 'fake_follower': 0.18, 'financial': 0.02, 'other': 0.31, 'overall': 0.31, 'self_declared': 0.03, 'spammer': 0.09}}, 'user': {'majority_lang': 'ur', 'user_data': {'id_str': '1407758671300362240', 'screen_name': 'Hashimalhanfi'}}}
# ======================= KMortha =======================
# {'cap': {'english': 0.6414184221423734, 'universal': 0.31739450135566455}, 'display_scores': {'english': {'astroturf': 0.4, 'fake_follower': 0.1, 'financial': 0.1, 'other': 0.8, 'overall': 0.8, 'self_declared': 0.0, 'spammer': 0.0}, 'universal': {'astroturf': 0.6, 'fake_follower': 0.1, 'financial': 0.1, 'other': 0.1, 'overall': 0.2, 'self_declared': 0.0, 'spammer': 0.0}}, 'raw_scores': {'english': {'astroturf': 0.08, 'fake_follower': 0.02, 'financial': 0.02, 'other': 0.15, 'overall': 0.17, 'self_declared': 0.0, 'spammer': 0.01}, 'universal': {'astroturf': 0.12, 'fake_follower': 0.02, 'financial': 0.02, 'other': 0.02, 'overall': 0.04, 'self_declared': 0.0, 'spammer': 0.0}}, 'user': {'majority_lang': 'en', 'user_data': {'id_str': '2296471495', 'screen_name': 'KMortha'}}}
# ======================= ProudIndian_253 =======================
# {'cap': {'english': 0.7470839770895665, 'universal': 0.7784494983408411}, 'display_scores': {'english': {'astroturf': 0.7, 'fake_follower': 0.6, 'financial': 0.0, 'other': 2.2, 'overall': 1.2, 'self_declared': 0.0, 'spammer': 0.4}, 'universal': {'astroturf': 1.0, 'fake_follower': 0.4, 'financial': 0.0, 'other': 1.2, 'overall': 1.4, 'self_declared': 0.0, 'spammer': 0.2}}, 'raw_scores': {'english': {'astroturf': 0.14, 'fake_follower': 0.11, 'financial': 0.0, 'other': 0.44, 'overall': 0.25, 'self_declared': 0.01, 'spammer': 0.09}, 'universal': {'astroturf': 0.2, 'fake_follower': 0.08, 'financial': 0.0, 'other': 0.23, 'overall': 0.28, 'self_declared': 0.01, 'spammer': 0.05}}, 'user': {'majority_lang': 'en', 'user_data': {'id_str': '1449071721768620036', 'screen_name': 'ProudIndian_253'}}}
# ======================= chandrats06 =======================
# {'cap': {'english': 0.5027122940873614, 'universal': 0.6608500314332488}, 'display_scores': {'english': {'astroturf': 0.4, 'fake_follower': 0.9, 'financial': 0.3, 'other': 0.8, 'overall': 0.6, 'self_declared': 0.1, 'spammer': 0.1}, 'universal': {'astroturf': 0.2, 'fake_follower': 0.8, 'financial': 0.2, 'other': 0.9, 'overall': 0.8, 'self_declared': 0.0, 'spammer': 0.4}}, 'raw_scores': {'english': {'astroturf': 0.09, 'fake_follower': 0.18, 'financial': 0.06, 'other': 0.15, 'overall': 0.11, 'self_declared': 0.02, 'spammer': 0.02}, 'universal': {'astroturf': 0.05, 'fake_follower': 0.15, 'financial': 0.05, 'other': 0.18, 'overall': 0.17, 'self_declared': 0.01, 'spammer': 0.07}}, 'user': {'majority_lang': 'en', 'user_data': {'id_str': '1322540669529919493', 'screen_name': 'chandrats06'}}}
# ======================= lemonchusleee =======================
# {'cap': {'english': 0.7967905786038864, 'universal': 0.7437205366967014}, 'display_scores': {'english': {'astroturf': 1.3, 'fake_follower': 1.0, 'financial': 1.4, 'other': 2.9, 'overall': 2.9, 'self_declared': 0.0, 'spammer': 0.3}, 'universal': {'astroturf': 0.8, 'fake_follower': 0.8, 'financial': 0.9, 'other': 2.3, 'overall': 1.2, 'self_declared': 0.2, 'spammer': 0.1}}, 'raw_scores': {'english': {'astroturf': 0.26, 'fake_follower': 0.21, 'financial': 0.28, 'other': 0.59, 'overall': 0.59, 'self_declared': 0.0, 'spammer': 0.06}, 'universal': {'astroturf': 0.17, 'fake_follower': 0.15, 'financial': 0.18, 'other': 0.46, 'overall': 0.23, 'self_declared': 0.03, 'spammer': 0.02}}, 'user': {'majority_lang': 'en', 'user_data': {'id_str': '1209219713139724289', 'screen_name': 'lemonchusleee'}}}
# ======================= zubair7409 =======================
# {'cap': {'english': 0.7759887465100499, 'universal': 0.4658392474232361}, 'display_scores': {'english': {'astroturf': 0.3, 'fake_follower': 0.4, 'financial': 0.4, 'other': 2.2, 'overall': 1.5, 'self_declared': 0.1, 'spammer': 0.1}, 'universal': {'astroturf': 0.2, 'fake_follower': 0.0, 'financial': 0.1, 'other': 0.8, 'overall': 0.4, 'self_declared': 0.0, 'spammer': 0.0}}, 'raw_scores': {'english': {'astroturf': 0.06, 'fake_follower': 0.07, 'financial': 0.09, 'other': 0.44, 'overall': 0.3, 'self_declared': 0.02, 'spammer': 0.02}, 'universal': {'astroturf': 0.03, 'fake_follower': 0.01, 'financial': 0.02, 'other': 0.15, 'overall': 0.09, 'self_declared': 0.0, 'spammer': 0.0}}, 'user': {'majority_lang': 'hi', 'user_data': {'id_str': '1235421182549061634', 'screen_name': 'zubair7409'}}}
# ======================= Md35556134 =======================
# {'cap': {'english': 0.7759887465100499, 'universal': 0.7674214324358889}, 'display_scores': {'english': {'astroturf': 1.2, 'fake_follower': 1.1, 'financial': 0.4, 'other': 2.2, 'overall': 1.5, 'self_declared': 0.2, 'spammer': 0.2}, 'universal': {'astroturf': 1.3, 'fake_follower': 0.8, 'financial': 0.2, 'other': 1.2, 'overall': 1.3, 'self_declared': 0.2, 'spammer': 0.2}}, 'raw_scores': {'english': {'astroturf': 0.25, 'fake_follower': 0.22, 'financial': 0.09, 'other': 0.43, 'overall': 0.3, 'self_declared': 0.03, 'spammer': 0.04}, 'universal': {'astroturf': 0.26, 'fake_follower': 0.16, 'financial': 0.04, 'other': 0.24, 'overall': 0.26, 'self_declared': 0.03, 'spammer': 0.04}}, 'user': {'majority_lang': 'en', 'user_data': {'id_str': '1448030208620064771', 'screen_name': 'Md35556134'}}}
# ======================= Sreedha24324771 =======================
# {'cap': {'english': 0.7546218700467833, 'universal': 0.7437205366967014}, 'display_scores': {'english': {'astroturf': 1.0, 'fake_follower': 0.4, 'financial': 0.0, 'other': 1.4, 'overall': 1.3, 'self_declared': 0.1, 'spammer': 0.6}, 'universal': {'astroturf': 0.6, 'fake_follower': 0.9, 'financial': 0.0, 'other': 1.4, 'overall': 1.2, 'self_declared': 0.0, 'spammer': 0.6}}, 'raw_scores': {'english': {'astroturf': 0.2, 'fake_follower': 0.07, 'financial': 0.01, 'other': 0.28, 'overall': 0.26, 'self_declared': 0.02, 'spammer': 0.11}, 'universal': {'astroturf': 0.12, 'fake_follower': 0.18, 'financial': 0.01, 'other': 0.29, 'overall': 0.23, 'self_declared': 0.01, 'spammer': 0.13}}, 'user': {'majority_lang': 'en', 'user_data': {'id_str': '1426512395485253634', 'screen_name': 'Sreedha24324771'}}}
# ======================= Iamraje78412219 =======================
# {'cap': {'english': 0.7759887465100499, 'universal': 0.799570188835745}, 'display_scores': {'english': {'astroturf': 1.0, 'fake_follower': 1.5, 'financial': 0.2, 'other': 2.5, 'overall': 1.5, 'self_declared': 2.2, 'spammer': 1.4}, 'universal': {'astroturf': 1.4, 'fake_follower': 1.8, 'financial': 0.2, 'other': 2.8, 'overall': 1.8, 'self_declared': 2.2, 'spammer': 1.4}}, 'raw_scores': {'english': {'astroturf': 0.21, 'fake_follower': 0.3, 'financial': 0.04, 'other': 0.5, 'overall': 0.3, 'self_declared': 0.43, 'spammer': 0.27}, 'universal': {'astroturf': 0.27, 'fake_follower': 0.35, 'financial': 0.05, 'other': 0.57, 'overall': 0.36, 'self_declared': 0.44, 'spammer': 0.28}}, 'user': {'majority_lang': 'en', 'user_data': {'id_str': '1512002307331801095', 'screen_name': 'Iamraje78412219'}}}
# ======================= Shaikhm04230983 =======================
# {'cap': {'english': 0.7717813288270262, 'universal': 0.4658392474232361}, 'display_scores': {'english': {'astroturf': 0.5, 'fake_follower': 1.0, 'financial': 0.2, 'other': 2.9, 'overall': 1.4, 'self_declared': 0.1, 'spammer': 0.2}, 'universal': {'astroturf': 0.2, 'fake_follower': 0.4, 'financial': 0.0, 'other': 0.7, 'overall': 0.4, 'self_declared': 0.0, 'spammer': 0.0}}, 'raw_scores': {'english': {'astroturf': 0.1, 'fake_follower': 0.21, 'financial': 0.03, 'other': 0.59, 'overall': 0.29, 'self_declared': 0.02, 'spammer': 0.04}, 'universal': {'astroturf': 0.04, 'fake_follower': 0.08, 'financial': 0.01, 'other': 0.14, 'overall': 0.09, 'self_declared': 0.01, 'spammer': 0.01}}, 'user': {'majority_lang': 'hi', 'user_data': {'id_str': '1275750684189753347', 'screen_name': 'Shaikhm04230983'}}}
# ======================= cricketspr =======================
# {'cap': {'english': 0.797782173166965, 'universal': 0.8082278383974655}, 'display_scores': {'english': {'astroturf': 0.1, 'fake_follower': 3.2, 'financial': 0.8, 'other': 3.5, 'overall': 3.5, 'self_declared': 1.9, 'spammer': 0.5}, 'universal': {'astroturf': 0.0, 'fake_follower': 3.6, 'financial': 1.0, 'other': 3.5, 'overall': 3.6, 'self_declared': 2.5, 'spammer': 0.4}}, 'raw_scores': {'english': {'astroturf': 0.02, 'fake_follower': 0.64, 'financial': 0.17, 'other': 0.7, 'overall': 0.7, 'self_declared': 0.38, 'spammer': 0.1}, 'universal': {'astroturf': 0.01, 'fake_follower': 0.73, 'financial': 0.21, 'other': 0.7, 'overall': 0.73, 'self_declared': 0.5, 'spammer': 0.09}}, 'user': {'majority_lang': 'en', 'user_data': {'id_str': '2595329342', 'screen_name': 'cricketspr'}}}
# ======================= yaji63 =======================
# {'cap': {'english': 0.7759887465100499, 'universal': 0.7784494983408411}, 'display_scores': {'english': {'astroturf': 1.0, 'fake_follower': 1.2, 'financial': 0.0, 'other': 1.4, 'overall': 1.5, 'self_declared': 0.2, 'spammer': 0.7}, 'universal': {'astroturf': 1.2, 'fake_follower': 1.0, 'financial': 0.2, 'other': 1.7, 'overall': 1.4, 'self_declared': 0.1, 'spammer': 0.8}}, 'raw_scores': {'english': {'astroturf': 0.19, 'fake_follower': 0.23, 'financial': 0.0, 'other': 0.29, 'overall': 0.3, 'self_declared': 0.04, 'spammer': 0.14}, 'universal': {'astroturf': 0.25, 'fake_follower': 0.19, 'financial': 0.03, 'other': 0.34, 'overall': 0.28, 'self_declared': 0.02, 'spammer': 0.17}}, 'user': {'majority_lang': 'en', 'user_data': {'id_str': '1479427217838915585', 'screen_name': 'yaji63'}}}
# ======================= mrImteyaz8 =======================
# {'error': "TweepError: [{'message': 'Internal error', 'code': 131}]"}
# ======================= SkSuhael =======================
# {'cap': {'english': 0.7826357858330618, 'universal': 0.6784864269642225}, 'display_scores': {'english': {'astroturf': 0.6, 'fake_follower': 0.8, 'financial': 0.3, 'other': 2.6, 'overall': 1.6, 'self_declared': 0.0, 'spammer': 0.2}, 'universal': {'astroturf': 0.5, 'fake_follower': 0.4, 'financial': 0.0, 'other': 1.8, 'overall': 0.9, 'self_declared': 0.0, 'spammer': 0.2}}, 'raw_scores': {'english': {'astroturf': 0.12, 'fake_follower': 0.15, 'financial': 0.06, 'other': 0.51, 'overall': 0.32, 'self_declared': 0.01, 'spammer': 0.03}, 'universal': {'astroturf': 0.1, 'fake_follower': 0.09, 'financial': 0.0, 'other': 0.35, 'overall': 0.18, 'self_declared': 0.01, 'spammer': 0.05}}, 'user': {'majority_lang': 'en', 'user_data': {'id_str': '1129644313116176384', 'screen_name': 'SkSuhael'}}}
# ======================= ehram123 =======================
# {'cap': {'english': 0.5288664776112156, 'universal': 0.37678996390568303}, 'display_scores': {'english': {'astroturf': 0.4, 'fake_follower': 0.2, 'financial': 0.4, 'other': 1.2, 'overall': 0.6, 'self_declared': 0.2, 'spammer': 0.0}, 'universal': {'astroturf': 0.3, 'fake_follower': 0.2, 'financial': 0.0, 'other': 0.5, 'overall': 0.3, 'self_declared': 0.1, 'spammer': 0.0}}, 'raw_scores': {'english': {'astroturf': 0.08, 'fake_follower': 0.04, 'financial': 0.08, 'other': 0.25, 'overall': 0.12, 'self_declared': 0.03, 'spammer': 0.01}, 'universal': {'astroturf': 0.06, 'fake_follower': 0.03, 'financial': 0.0, 'other': 0.1, 'overall': 0.06, 'self_declared': 0.02, 'spammer': 0.0}}, 'user': {'majority_lang': 'en', 'user_data': {'id_str': '73215939', 'screen_name': 'ehram123'}}}
# ======================= _irrationality0 =======================
# {'cap': {'english': 0.7759887465100499, 'universal': 0.8030212452554465}, 'display_scores': {'english': {'astroturf': 0.8, 'fake_follower': 2.2, 'financial': 0.8, 'other': 1.8, 'overall': 1.5, 'self_declared': 0.2, 'spammer': 1.0}, 'universal': {'astroturf': 0.4, 'fake_follower': 2.0, 'financial': 0.6, 'other': 2.0, 'overall': 2.0, 'self_declared': 0.1, 'spammer': 0.8}}, 'raw_scores': {'english': {'astroturf': 0.16, 'fake_follower': 0.45, 'financial': 0.15, 'other': 0.36, 'overall': 0.3, 'self_declared': 0.05, 'spammer': 0.2}, 'universal': {'astroturf': 0.08, 'fake_follower': 0.4, 'financial': 0.13, 'other': 0.41, 'overall': 0.4, 'self_declared': 0.02, 'spammer': 0.17}}, 'user': {'majority_lang': 'en', 'user_data': {'id_str': '1536495364731068417', 'screen_name': '_irrationality0'}}}
# ======================= tradingfutures1 =======================
# {'cap': {'english': 0.7287106185584935, 'universal': 0.37678996390568303}, 'display_scores': {'english': {'astroturf': 0.8, 'fake_follower': 0.4, 'financial': 0.2, 'other': 1.5, 'overall': 1.2, 'self_declared': 0.0, 'spammer': 0.2}, 'universal': {'astroturf': 0.6, 'fake_follower': 0.4, 'financial': 0.0, 'other': 0.4, 'overall': 0.3, 'self_declared': 0.0, 'spammer': 0.1}}, 'raw_scores': {'english': {'astroturf': 0.16, 'fake_follower': 0.07, 'financial': 0.03, 'other': 0.3, 'overall': 0.23, 'self_declared': 0.0, 'spammer': 0.04}, 'universal': {'astroturf': 0.13, 'fake_follower': 0.09, 'financial': 0.01, 'other': 0.07, 'overall': 0.06, 'self_declared': 0.0, 'spammer': 0.02}}, 'user': {'majority_lang': 'fr', 'user_data': {'id_str': '173088159', 'screen_name': 'tradingfutures1'}}}
# ======================= SankarsanBarik4 =======================
# {'cap': {'english': 0.6004883262510591, 'universal': 0.5222398722127631}, 'display_scores': {'english': {'astroturf': 0.9, 'fake_follower': 0.8, 'financial': 0.0, 'other': 1.6, 'overall': 0.8, 'self_declared': 0.0, 'spammer': 0.0}, 'universal': {'astroturf': 1.4, 'fake_follower': 0.4, 'financial': 0.0, 'other': 1.1, 'overall': 0.6, 'self_declared': 0.1, 'spammer': 0.0}}, 'raw_scores': {'english': {'astroturf': 0.18, 'fake_follower': 0.17, 'financial': 0.0, 'other': 0.33, 'overall': 0.15, 'self_declared': 0.0, 'spammer': 0.01}, 'universal': {'astroturf': 0.29, 'fake_follower': 0.08, 'financial': 0.01, 'other': 0.22, 'overall': 0.11, 'self_declared': 0.02, 'spammer': 0.01}}, 'user': {'majority_lang': 'en', 'user_data': {'id_str': '982511045519466497', 'screen_name': 'SankarsanBarik4'}}}
# ======================= TarunKGupta2 =======================
# {'cap': {'english': 0.6004883262510591, 'universal': 0.5488888157824968}, 'display_scores': {'english': {'astroturf': 1.4, 'fake_follower': 0.6, 'financial': 0.2, 'other': 1.6, 'overall': 0.8, 'self_declared': 0.1, 'spammer': 0.4}, 'universal': {'astroturf': 1.2, 'fake_follower': 1.1, 'financial': 0.0, 'other': 0.8, 'overall': 0.6, 'self_declared': 0.0, 'spammer': 0.1}}, 'raw_scores': {'english': {'astroturf': 0.27, 'fake_follower': 0.13, 'financial': 0.03, 'other': 0.32, 'overall': 0.15, 'self_declared': 0.02, 'spammer': 0.07}, 'universal': {'astroturf': 0.25, 'fake_follower': 0.22, 'financial': 0.01, 'other': 0.15, 'overall': 0.12, 'self_declared': 0.01, 'spammer': 0.02}}, 'user': {'majority_lang': 'en', 'user_data': {'id_str': '531482333', 'screen_name': 'TarunKGupta2'}}}
# ======================= canarayan1 =======================
# {'cap': {'english': 0.797075908158591, 'universal': 0.8068955728616037}, 'display_scores': {'english': {'astroturf': 0.6, 'fake_follower': 1.7, 'financial': 0.7, 'other': 3.4, 'overall': 3.4, 'self_declared': 2.5, 'spammer': 0.9}, 'universal': {'astroturf': 0.8, 'fake_follower': 2.2, 'financial': 1.0, 'other': 3.6, 'overall': 3.6, 'self_declared': 2.3, 'spammer': 0.7}}, 'raw_scores': {'english': {'astroturf': 0.12, 'fake_follower': 0.34, 'financial': 0.14, 'other': 0.68, 'overall': 0.68, 'self_declared': 0.5, 'spammer': 0.18}, 'universal': {'astroturf': 0.17, 'fake_follower': 0.43, 'financial': 0.2, 'other': 0.71, 'overall': 0.71, 'self_declared': 0.46, 'spammer': 0.14}}, 'user': {'majority_lang': 'en', 'user_data': {'id_str': '859400293', 'screen_name': 'canarayan1'}}}
# ======================= KiranKumarGK1 =======================
# {'cap': {'english': 0.8670116134145492, 'universal': 0.8372129323854712}, 'display_scores': {'english': {'astroturf': 0.0, 'fake_follower': 3.9, 'financial': 0.2, 'other': 4.5, 'overall': 4.5, 'self_declared': 3.4, 'spammer': 2.6}, 'universal': {'astroturf': 0.0, 'fake_follower': 2.8, 'financial': 0.4, 'other': 4.2, 'overall': 4.2, 'self_declared': 3.8, 'spammer': 1.3}}, 'raw_scores': {'english': {'astroturf': 0.0, 'fake_follower': 0.78, 'financial': 0.03, 'other': 0.9, 'overall': 0.9, 'self_declared': 0.67, 'spammer': 0.51}, 'universal': {'astroturf': 0.0, 'fake_follower': 0.57, 'financial': 0.09, 'other': 0.85, 'overall': 0.85, 'self_declared': 0.76, 'spammer': 0.26}}, 'user': {'majority_lang': 'kn', 'user_data': {'id_str': '2568677935', 'screen_name': 'KiranKumarGK1'}}}
# ======================= Avijit3k2 =======================
# {'cap': {'english': 0.4197222421546159, 'universal': 0.5222398722127631}, 'display_scores': {'english': {'astroturf': 1.2, 'fake_follower': 0.2, 'financial': 0.0, 'other': 0.6, 'overall': 0.4, 'self_declared': 0.0, 'spammer': 0.2}, 'universal': {'astroturf': 1.0, 'fake_follower': 0.4, 'financial': 0.0, 'other': 0.9, 'overall': 0.6, 'self_declared': 0.0, 'spammer': 0.2}}, 'raw_scores': {'english': {'astroturf': 0.25, 'fake_follower': 0.04, 'financial': 0.0, 'other': 0.11, 'overall': 0.08, 'self_declared': 0.0, 'spammer': 0.03}, 'universal': {'astroturf': 0.2, 'fake_follower': 0.07, 'financial': 0.0, 'other': 0.18, 'overall': 0.11, 'self_declared': 0.0, 'spammer': 0.03}}, 'user': {'majority_lang': 'en', 'user_data': {'id_str': '1047909697', 'screen_name': 'Avijit3k2'}}}
# ======================= ramanvk819 =======================
# {'cap': {'english': 0.6915799517497913, 'universal': 0.6415870166679795}, 'display_scores': {'english': {'astroturf': 0.2, 'fake_follower': 1.0, 'financial': 0.3, 'other': 3.0, 'overall': 1.0, 'self_declared': 2.7, 'spammer': 0.4}, 'universal': {'astroturf': 0.6, 'fake_follower': 0.9, 'financial': 0.2, 'other': 2.0, 'overall': 0.8, 'self_declared': 1.9, 'spammer': 0.4}}, 'raw_scores': {'english': {'astroturf': 0.05, 'fake_follower': 0.19, 'financial': 0.06, 'other': 0.6, 'overall': 0.2, 'self_declared': 0.53, 'spammer': 0.09}, 'universal': {'astroturf': 0.11, 'fake_follower': 0.18, 'financial': 0.05, 'other': 0.41, 'overall': 0.16, 'self_declared': 0.38, 'spammer': 0.08}}, 'user': {'majority_lang': 'en', 'user_data': {'id_str': '311479293', 'screen_name': 'ramanvk819'}}}
# ======================= Pj_Keshriyagrp =======================
# {'cap': {'english': 0.4197222421546159, 'universal': 0.28846389695411967}, 'display_scores': {'english': {'astroturf': 0.8, 'fake_follower': 0.1, 'financial': 0.0, 'other': 0.8, 'overall': 0.4, 'self_declared': 0.0, 'spammer': 0.1}, 'universal': {'astroturf': 0.7, 'fake_follower': 0.0, 'financial': 0.0, 'other': 0.4, 'overall': 0.2, 'self_declared': 0.0, 'spammer': 0.2}}, 'raw_scores': {'english': {'astroturf': 0.15, 'fake_follower': 0.02, 'financial': 0.0, 'other': 0.17, 'overall': 0.08, 'self_declared': 0.0, 'spammer': 0.02}, 'universal': {'astroturf': 0.14, 'fake_follower': 0.0, 'financial': 0.0, 'other': 0.09, 'overall': 0.03, 'self_declared': 0.0, 'spammer': 0.03}}, 'user': {'majority_lang': 'en', 'user_data': {'id_str': '1159398170176004098', 'screen_name': 'Pj_Keshriyagrp'}}}
# ======================= JaiPoori =======================
# {'cap': {'english': 0.7546218700467833, 'universal': 0.5488888157824968}, 'display_scores': {'english': {'astroturf': 0.2, 'fake_follower': 1.4, 'financial': 0.2, 'other': 1.2, 'overall': 1.3, 'self_declared': 0.2, 'spammer': 0.4}, 'universal': {'astroturf': 0.4, 'fake_follower': 1.1, 'financial': 0.0, 'other': 0.6, 'overall': 0.6, 'self_declared': 0.3, 'spammer': 0.7}}, 'raw_scores': {'english': {'astroturf': 0.04, 'fake_follower': 0.29, 'financial': 0.03, 'other': 0.25, 'overall': 0.26, 'self_declared': 0.05, 'spammer': 0.08}, 'universal': {'astroturf': 0.09, 'fake_follower': 0.22, 'financial': 0.01, 'other': 0.11, 'overall': 0.12, 'self_declared': 0.06, 'spammer': 0.14}}, 'user': {'majority_lang': 'en', 'user_data': {'id_str': '1538669778461671427', 'screen_name': 'JaiPoori'}}}
# ======================= aamehta1980 =======================
# {'cap': {'english': 0.7717813288270262, 'universal': 0.6608500314332488}, 'display_scores': {'english': {'astroturf': 0.2, 'fake_follower': 1.4, 'financial': 0.4, 'other': 0.8, 'overall': 1.4, 'self_declared': 0.0, 'spammer': 1.0}, 'universal': {'astroturf': 0.3, 'fake_follower': 0.6, 'financial': 0.2, 'other': 0.8, 'overall': 0.8, 'self_declared': 0.2, 'spammer': 0.8}}, 'raw_scores': {'english': {'astroturf': 0.03, 'fake_follower': 0.27, 'financial': 0.08, 'other': 0.15, 'overall': 0.29, 'self_declared': 0.0, 'spammer': 0.2}, 'universal': {'astroturf': 0.06, 'fake_follower': 0.11, 'financial': 0.05, 'other': 0.17, 'overall': 0.17, 'self_declared': 0.03, 'spammer': 0.15}}, 'user': {'majority_lang': 'en', 'user_data': {'id_str': '137610583', 'screen_name': 'aamehta1980'}}}
# ======================= Subash37006856 =======================
# {'cap': {'english': 0.2787259978325127, 'universal': 0.2603678379426137}, 'display_scores': {'english': {'astroturf': 0.6, 'fake_follower': 0.7, 'financial': 0.0, 'other': 0.6, 'overall': 0.2, 'self_declared': 0.0, 'spammer': 0.0}, 'universal': {'astroturf': 0.7, 'fake_follower': 0.8, 'financial': 0.1, 'other': 0.4, 'overall': 0.1, 'self_declared': 0.1, 'spammer': 0.0}}, 'raw_scores': {'english': {'astroturf': 0.13, 'fake_follower': 0.14, 'financial': 0.01, 'other': 0.12, 'overall': 0.03, 'self_declared': 0.01, 'spammer': 0.01}, 'universal': {'astroturf': 0.14, 'fake_follower': 0.17, 'financial': 0.02, 'other': 0.08, 'overall': 0.02, 'self_declared': 0.02, 'spammer': 0.0}}, 'user': {'majority_lang': 'en', 'user_data': {'id_str': '1286276649147719681', 'screen_name': 'Subash37006856'}}}
# ======================= underpaidsevak =======================
# {'cap': {'english': 0.6414184221423734, 'universal': 0.792436790569533}, 'display_scores': {'english': {'astroturf': 0.0, 'fake_follower': 1.8, 'financial': 0.2, 'other': 0.8, 'overall': 0.8, 'self_declared': 0.2, 'spammer': 0.6}, 'universal': {'astroturf': 0.6, 'fake_follower': 2.2, 'financial': 0.2, 'other': 1.8, 'overall': 1.6, 'self_declared': 0.2, 'spammer': 0.8}}, 'raw_scores': {'english': {'astroturf': 0.01, 'fake_follower': 0.36, 'financial': 0.04, 'other': 0.17, 'overall': 0.17, 'self_declared': 0.04, 'spammer': 0.11}, 'universal': {'astroturf': 0.11, 'fake_follower': 0.43, 'financial': 0.05, 'other': 0.36, 'overall': 0.32, 'self_declared': 0.03, 'spammer': 0.15}}, 'user': {'majority_lang': 'en', 'user_data': {'id_str': '1495071088296214528', 'screen_name': 'underpaidsevak'}}}
# ======================= Manishis050 =======================
# {'cap': {'english': 0.796599114745521, 'universal': 0.7947108099739177}, 'display_scores': {'english': {'astroturf': 0.9, 'fake_follower': 2.4, 'financial': 1.8, 'other': 3.2, 'overall': 3.2, 'self_declared': 0.2, 'spammer': 0.1}, 'universal': {'astroturf': 1.0, 'fake_follower': 2.0, 'financial': 1.0, 'other': 2.3, 'overall': 1.6, 'self_declared': 0.2, 'spammer': 0.2}}, 'raw_scores': {'english': {'astroturf': 0.18, 'fake_follower': 0.49, 'financial': 0.36, 'other': 0.64, 'overall': 0.64, 'self_declared': 0.05, 'spammer': 0.02}, 'universal': {'astroturf': 0.21, 'fake_follower': 0.39, 'financial': 0.2, 'other': 0.47, 'overall': 0.33, 'self_declared': 0.03, 'spammer': 0.04}}, 'user': {'majority_lang': 'en', 'user_data': {'id_str': '189132754', 'screen_name': 'Manishis050'}}}
# ======================= NikhilRaod =======================
# {'cap': {'english': 0.7287106185584935, 'universal': 0.6415870166679795}, 'display_scores': {'english': {'astroturf': 0.4, 'fake_follower': 1.1, 'financial': 0.3, 'other': 0.2, 'overall': 1.2, 'self_declared': 0.1, 'spammer': 0.2}, 'universal': {'astroturf': 0.8, 'fake_follower': 0.8, 'financial': 0.4, 'other': 0.7, 'overall': 0.8, 'self_declared': 0.0, 'spammer': 0.2}}, 'raw_scores': {'english': {'astroturf': 0.07, 'fake_follower': 0.22, 'financial': 0.06, 'other': 0.05, 'overall': 0.23, 'self_declared': 0.02, 'spammer': 0.04}, 'universal': {'astroturf': 0.17, 'fake_follower': 0.15, 'financial': 0.08, 'other': 0.14, 'overall': 0.16, 'self_declared': 0.0, 'spammer': 0.05}}, 'user': {'majority_lang': 'en', 'user_data': {'id_str': '1534703463241641984', 'screen_name': 'NikhilRaod'}}}
# ======================= asifmohd63 =======================
# {'cap': {'english': 0.7907586934369296, 'universal': 0.3469210182245441}, 'display_scores': {'english': {'astroturf': 0.6, 'fake_follower': 0.8, 'financial': 0.2, 'other': 2.8, 'overall': 1.8, 'self_declared': 0.0, 'spammer': 0.4}, 'universal': {'astroturf': 0.5, 'fake_follower': 0.4, 'financial': 0.0, 'other': 0.5, 'overall': 0.2, 'self_declared': 0.0, 'spammer': 0.1}}, 'raw_scores': {'english': {'astroturf': 0.11, 'fake_follower': 0.17, 'financial': 0.05, 'other': 0.56, 'overall': 0.36, 'self_declared': 0.0, 'spammer': 0.09}, 'universal': {'astroturf': 0.1, 'fake_follower': 0.09, 'financial': 0.0, 'other': 0.1, 'overall': 0.05, 'self_declared': 0.0, 'spammer': 0.02}}, 'user': {'majority_lang': 'hi', 'user_data': {'id_str': '992290426966102017', 'screen_name': 'asifmohd63'}}}
# ======================= ra54077891 =======================
# {'cap': {'english': 0.8995513244218455, 'universal': 0.9121502174127201}, 'display_scores': {'english': {'astroturf': 0.2, 'fake_follower': 4.7, 'financial': 1.0, 'other': 4.0, 'overall': 4.7, 'self_declared': 2.8, 'spammer': 3.0}, 'universal': {'astroturf': 0.0, 'fake_follower': 4.8, 'financial': 1.6, 'other': 3.8, 'overall': 4.8, 'self_declared': 3.6, 'spammer': 1.9}}, 'raw_scores': {'english': {'astroturf': 0.03, 'fake_follower': 0.94, 'financial': 0.19, 'other': 0.8, 'overall': 0.94, 'self_declared': 0.56, 'spammer': 0.61}, 'universal': {'astroturf': 0.0, 'fake_follower': 0.96, 'financial': 0.31, 'other': 0.76, 'overall': 0.96, 'self_declared': 0.72, 'spammer': 0.38}}, 'user': {'majority_lang': 'qht', 'user_data': {'id_str': '1327314895050735616', 'screen_name': 'ra54077891'}}}
# ======================= rajarshi_sg =======================
# {'cap': {'english': 0.7967206940193189, 'universal': 0.801617083559931}, 'display_scores': {'english': {'astroturf': 0.2, 'fake_follower': 1.6, 'financial': 0.2, 'other': 3.3, 'overall': 3.3, 'self_declared': 2.4, 'spammer': 0.5}, 'universal': {'astroturf': 0.2, 'fake_follower': 1.0, 'financial': 0.2, 'other': 2.8, 'overall': 1.9, 'self_declared': 3.0, 'spammer': 0.8}}, 'raw_scores': {'english': {'astroturf': 0.05, 'fake_follower': 0.33, 'financial': 0.05, 'other': 0.66, 'overall': 0.66, 'self_declared': 0.49, 'spammer': 0.1}, 'universal': {'astroturf': 0.05, 'fake_follower': 0.2, 'financial': 0.04, 'other': 0.57, 'overall': 0.38, 'self_declared': 0.6, 'spammer': 0.16}}, 'user': {'majority_lang': 'en', 'user_data': {'id_str': '186480584', 'screen_name': 'rajarshi_sg'}}}
# ======================= MaskMan17122213 =======================
# {'cap': {'english': 0.7939576449836836, 'universal': 0.43650814830094437}, 'display_scores': {'english': {'astroturf': 0.4, 'fake_follower': 1.6, 'financial': 0.2, 'other': 1.8, 'overall': 2.0, 'self_declared': 0.2, 'spammer': 0.4}, 'universal': {'astroturf': 0.8, 'fake_follower': 1.1, 'financial': 0.2, 'other': 0.6, 'overall': 0.4, 'self_declared': 0.2, 'spammer': 0.4}}, 'raw_scores': {'english': {'astroturf': 0.09, 'fake_follower': 0.33, 'financial': 0.03, 'other': 0.36, 'overall': 0.39, 'self_declared': 0.04, 'spammer': 0.09}, 'universal': {'astroturf': 0.17, 'fake_follower': 0.22, 'financial': 0.03, 'other': 0.12, 'overall': 0.08, 'self_declared': 0.04, 'spammer': 0.09}}, 'user': {'majority_lang': 'hi', 'user_data': {'id_str': '1399052988610613252', 'screen_name': 'MaskMan17122213'}}}
# ======================= Notsoyoung5 =======================
# {'error': 'TweepError: Not authorized.'}
# ======================= Sid95879 =======================
# {'cap': {'english': 0.659646495284545, 'universal': 0.49449072748283696}, 'display_scores': {'english': {'astroturf': 0.4, 'fake_follower': 0.7, 'financial': 0.2, 'other': 2.0, 'overall': 0.9, 'self_declared': 0.3, 'spammer': 0.4}, 'universal': {'astroturf': 0.2, 'fake_follower': 0.8, 'financial': 0.1, 'other': 1.2, 'overall': 0.5, 'self_declared': 0.0, 'spammer': 0.2}}, 'raw_scores': {'english': {'astroturf': 0.07, 'fake_follower': 0.14, 'financial': 0.03, 'other': 0.4, 'overall': 0.18, 'self_declared': 0.06, 'spammer': 0.08}, 'universal': {'astroturf': 0.04, 'fake_follower': 0.15, 'financial': 0.02, 'other': 0.23, 'overall': 0.1, 'self_declared': 0.0, 'spammer': 0.04}}, 'user': {'majority_lang': 'en', 'user_data': {'id_str': '1370248157917970435', 'screen_name': 'Sid95879'}}}
# ======================= anbokshi =======================
# {'cap': {'english': 0.7384783166429812, 'universal': 0.5742686032713971}, 'display_scores': {'english': {'astroturf': 0.4, 'fake_follower': 0.4, 'financial': 0.0, 'other': 2.4, 'overall': 1.2, 'self_declared': 0.3, 'spammer': 0.1}, 'universal': {'astroturf': 0.2, 'fake_follower': 0.2, 'financial': 0.1, 'other': 1.8, 'overall': 0.6, 'self_declared': 0.2, 'spammer': 0.0}}, 'raw_scores': {'english': {'astroturf': 0.08, 'fake_follower': 0.09, 'financial': 0.0, 'other': 0.49, 'overall': 0.24, 'self_declared': 0.06, 'spammer': 0.02}, 'universal': {'astroturf': 0.03, 'fake_follower': 0.03, 'financial': 0.02, 'other': 0.37, 'overall': 0.13, 'self_declared': 0.04, 'spammer': 0.01}}, 'user': {'majority_lang': 'en', 'user_data': {'id_str': '987032813802278915', 'screen_name': 'anbokshi'}}}
# ======================= dryahyakazi =======================
# {'cap': {'english': 0.7892294694438972, 'universal': 0.4658392474232361}, 'display_scores': {'english': {'astroturf': 0.4, 'fake_follower': 1.0, 'financial': 0.2, 'other': 2.6, 'overall': 1.8, 'self_declared': 0.2, 'spammer': 0.8}, 'universal': {'astroturf': 0.2, 'fake_follower': 0.4, 'financial': 0.0, 'other': 1.4, 'overall': 0.4, 'self_declared': 0.0, 'spammer': 0.0}}, 'raw_scores': {'english': {'astroturf': 0.09, 'fake_follower': 0.21, 'financial': 0.03, 'other': 0.52, 'overall': 0.35, 'self_declared': 0.04, 'spammer': 0.15}, 'universal': {'astroturf': 0.04, 'fake_follower': 0.09, 'financial': 0.01, 'other': 0.28, 'overall': 0.09, 'self_declared': 0.01, 'spammer': 0.0}}, 'user': {'majority_lang': 'ur', 'user_data': {'id_str': '2215026360', 'screen_name': 'dryahyakazi'}}}
# ======================= shanthala_kumar =======================
# {'cap': {'english': 0.6763619064808265, 'universal': 0.49449072748283696}, 'display_scores': {'english': {'astroturf': 0.6, 'fake_follower': 0.2, 'financial': 0.4, 'other': 0.6, 'overall': 1.0, 'self_declared': 0.2, 'spammer': 0.0}, 'universal': {'astroturf': 0.6, 'fake_follower': 0.2, 'financial': 0.2, 'other': 0.4, 'overall': 0.5, 'self_declared': 0.2, 'spammer': 0.0}}, 'raw_scores': {'english': {'astroturf': 0.12, 'fake_follower': 0.04, 'financial': 0.08, 'other': 0.12, 'overall': 0.19, 'self_declared': 0.04, 'spammer': 0.0}, 'universal': {'astroturf': 0.12, 'fake_follower': 0.04, 'financial': 0.04, 'other': 0.08, 'overall': 0.1, 'self_declared': 0.03, 'spammer': 0.01}}, 'user': {'majority_lang': 'en', 'user_data': {'id_str': '1301098695090298880', 'screen_name': 'shanthala_kumar'}}}
# ======================= Shweta_India =======================
# {'cap': {'english': 0.2787259978325127, 'universal': 0.43650814830094437}, 'display_scores': {'english': {'astroturf': 0.6, 'fake_follower': 0.0, 'financial': 0.0, 'other': 0.7, 'overall': 0.2, 'self_declared': 0.0, 'spammer': 0.0}, 'universal': {'astroturf': 0.7, 'fake_follower': 0.2, 'financial': 0.0, 'other': 0.7, 'overall': 0.4, 'self_declared': 0.0, 'spammer': 0.0}}, 'raw_scores': {'english': {'astroturf': 0.13, 'fake_follower': 0.01, 'financial': 0.0, 'other': 0.14, 'overall': 0.03, 'self_declared': 0.01, 'spammer': 0.01}, 'universal': {'astroturf': 0.14, 'fake_follower': 0.04, 'financial': 0.0, 'other': 0.14, 'overall': 0.08, 'self_declared': 0.0, 'spammer': 0.0}}, 'user': {'majority_lang': 'en', 'user_data': {'id_str': '1298964113822044160', 'screen_name': 'Shweta_India'}}}
# ======================= Srikarch11 =======================
# {'cap': {'english': 0.7952555385005927, 'universal': 0.8043181589918191}, 'display_scores': {'english': {'astroturf': 0.7, 'fake_follower': 0.7, 'financial': 0.2, 'other': 2.2, 'overall': 2.0, 'self_declared': 0.2, 'spammer': 1.6}, 'universal': {'astroturf': 0.5, 'fake_follower': 1.0, 'financial': 0.4, 'other': 1.3, 'overall': 2.2, 'self_declared': 0.2, 'spammer': 2.2}}, 'raw_scores': {'english': {'astroturf': 0.14, 'fake_follower': 0.14, 'financial': 0.05, 'other': 0.43, 'overall': 0.41, 'self_declared': 0.05, 'spammer': 0.33}, 'universal': {'astroturf': 0.1, 'fake_follower': 0.21, 'financial': 0.08, 'other': 0.26, 'overall': 0.43, 'self_declared': 0.04, 'spammer': 0.43}}, 'user': {'majority_lang': 'en', 'user_data': {'id_str': '1505233810903891970', 'screen_name': 'Srikarch11'}}}
# ======================= dinakar24 =======================
# {'error': "TweepError: [{'code': 34, 'message': 'Sorry, that page does not exist.'}]"}
# ======================= Namami_Ganga =======================
# {'cap': {'english': 0.6414184221423734, 'universal': 0.5222398722127631}, 'display_scores': {'english': {'astroturf': 1.6, 'fake_follower': 0.3, 'financial': 0.0, 'other': 2.0, 'overall': 0.8, 'self_declared': 0.0, 'spammer': 0.1}, 'universal': {'astroturf': 1.8, 'fake_follower': 0.4, 'financial': 0.0, 'other': 0.8, 'overall': 0.6, 'self_declared': 0.0, 'spammer': 0.0}}, 'raw_scores': {'english': {'astroturf': 0.31, 'fake_follower': 0.06, 'financial': 0.0, 'other': 0.41, 'overall': 0.17, 'self_declared': 0.0, 'spammer': 0.02}, 'universal': {'astroturf': 0.36, 'fake_follower': 0.07, 'financial': 0.0, 'other': 0.15, 'overall': 0.11, 'self_declared': 0.0, 'spammer': 0.0}}, 'user': {'majority_lang': 'en', 'user_data': {'id_str': '1596026516', 'screen_name': 'Namami_Ganga'}}}
# ======================= Lisali89880277 =======================
# {'cap': {'english': 0.8595061719862279, 'universal': 0.8885263643630983}, 'display_scores': {'english': {'astroturf': 0.2, 'fake_follower': 3.6, 'financial': 0.4, 'other': 4.2, 'overall': 4.4, 'self_declared': 4.4, 'spammer': 2.0}, 'universal': {'astroturf': 0.0, 'fake_follower': 3.4, 'financial': 0.8, 'other': 4.4, 'overall': 4.6, 'self_declared': 4.6, 'spammer': 2.4}}, 'raw_scores': {'english': {'astroturf': 0.04, 'fake_follower': 0.71, 'financial': 0.09, 'other': 0.85, 'overall': 0.89, 'self_declared': 0.89, 'spammer': 0.4}, 'universal': {'astroturf': 0.0, 'fake_follower': 0.68, 'financial': 0.17, 'other': 0.87, 'overall': 0.93, 'self_declared': 0.93, 'spammer': 0.48}}, 'user': {'majority_lang': 'en', 'user_data': {'id_str': '1532285898154442756', 'screen_name': 'Lisali89880277'}}}
# ======================= funnyface234 =======================
# {'cap': {'english': 0.797075908158591, 'universal': 0.8102129289660348}, 'display_scores': {'english': {'astroturf': 0.2, 'fake_follower': 3.4, 'financial': 0.4, 'other': 2.4, 'overall': 3.4, 'self_declared': 2.4, 'spammer': 2.0}, 'universal': {'astroturf': 0.4, 'fake_follower': 3.8, 'financial': 0.4, 'other': 3.0, 'overall': 3.8, 'self_declared': 2.7, 'spammer': 2.4}}, 'raw_scores': {'english': {'astroturf': 0.03, 'fake_follower': 0.68, 'financial': 0.09, 'other': 0.48, 'overall': 0.68, 'self_declared': 0.49, 'spammer': 0.4}, 'universal': {'astroturf': 0.07, 'fake_follower': 0.75, 'financial': 0.09, 'other': 0.6, 'overall': 0.75, 'self_declared': 0.53, 'spammer': 0.48}}, 'user': {'majority_lang': 'hi', 'user_data': {'id_str': '1536105936103800833', 'screen_name': 'funnyface234'}}}
# ======================= wind_duo =======================
# {'cap': {'english': 0.36264564124632276, 'universal': 0.6207049850511144}, 'display_scores': {'english': {'astroturf': 0.2, 'fake_follower': 0.2, 'financial': 0.0, 'other': 0.9, 'overall': 0.3, 'self_declared': 0.0, 'spammer': 0.0}, 'universal': {'astroturf': 0.2, 'fake_follower': 0.2, 'financial': 0.0, 'other': 0.9, 'overall': 0.8, 'self_declared': 0.0, 'spammer': 0.0}}, 'raw_scores': {'english': {'astroturf': 0.04, 'fake_follower': 0.04, 'financial': 0.0, 'other': 0.18, 'overall': 0.06, 'self_declared': 0.0, 'spammer': 0.0}, 'universal': {'astroturf': 0.03, 'fake_follower': 0.05, 'financial': 0.0, 'other': 0.18, 'overall': 0.15, 'self_declared': 0.0, 'spammer': 0.0}}, 'user': {'majority_lang': 'en', 'user_data': {'id_str': '2873324754', 'screen_name': 'wind_duo'}}}
# ======================= nayakSSekhar =======================
# {'cap': {'english': 0.3912159239072283, 'universal': 0.5222398722127631}, 'display_scores': {'english': {'astroturf': 0.2, 'fake_follower': 1.5, 'financial': 0.3, 'other': 0.9, 'overall': 0.4, 'self_declared': 0.0, 'spammer': 0.1}, 'universal': {'astroturf': 0.4, 'fake_follower': 0.9, 'financial': 0.2, 'other': 0.8, 'overall': 0.6, 'self_declared': 0.4, 'spammer': 0.0}}, 'raw_scores': {'english': {'astroturf': 0.03, 'fake_follower': 0.3, 'financial': 0.06, 'other': 0.18, 'overall': 0.07, 'self_declared': 0.01, 'spammer': 0.02}, 'universal': {'astroturf': 0.07, 'fake_follower': 0.18, 'financial': 0.03, 'other': 0.17, 'overall': 0.11, 'self_declared': 0.08, 'spammer': 0.01}}, 'user': {'majority_lang': 'en', 'user_data': {'id_str': '1073266741680103424', 'screen_name': 'nayakSSekhar'}}}
# ======================= tuubol =======================
# {'cap': {'english': 0.3912159239072283, 'universal': 0.23332432370635456}, 'display_scores': {'english': {'astroturf': 1.0, 'fake_follower': 0.0, 'financial': 0.4, 'other': 0.9, 'overall': 0.4, 'self_declared': 0.0, 'spammer': 0.0}, 'universal': {'astroturf': 1.2, 'fake_follower': 0.4, 'financial': 0.2, 'other': 0.2, 'overall': 0.0, 'self_declared': 0.0, 'spammer': 0.0}}, 'raw_scores': {'english': {'astroturf': 0.2, 'fake_follower': 0.01, 'financial': 0.08, 'other': 0.18, 'overall': 0.07, 'self_declared': 0.0, 'spammer': 0.0}, 'universal': {'astroturf': 0.23, 'fake_follower': 0.07, 'financial': 0.03, 'other': 0.05, 'overall': 0.01, 'self_declared': 0.01, 'spammer': 0.0}}, 'user': {'majority_lang': 'en', 'user_data': {'id_str': '278318282', 'screen_name': 'tuubol'}}}
# ...
# ======================= icekoolrahul =======================
# {'cap': {'english': 0.5778862084370772, 'universal': 0.0}, 'display_scores': {'english': {'astroturf': 0.8, 'fake_follower': 0.1, 'financial': 0.0, 'other': 1.2, 'overall': 0.7, 'self_declared': 0.0, 'spammer': 0.1}, 'universal': {'astroturf': 0.8, 'fake_follower': 0.0, 'financial': 0.0, 'other': 0.3, 'overall': 0.0, 'self_declared': 0.0, 'spammer': 0.0}}, 'raw_scores': {'english': {'astroturf': 0.16, 'fake_follower': 0.02, 'financial': 0.0, 'other': 0.23, 'overall': 0.14, 'self_declared': 0.01, 'spammer': 0.02}, 'universal': {'astroturf': 0.15, 'fake_follower': 0.0, 'financial': 0.0, 'other': 0.06, 'overall': 0.0, 'self_declared': 0.0, 'spammer': 0.01}}, 'user': {'majority_lang': 'en', 'user_data': {'id_str': '134782480', 'screen_name': 'icekoolrahul'}}}
# ======================= DipayanDMR =======================
# {'cap': {'english': 0.4197222421546159, 'universal': 0.28846389695411967}, 'display_scores': {'english': {'astroturf': 0.2, 'fake_follower': 0.2, 'financial': 0.0, 'other': 0.6, 'overall': 0.4, 'self_declared': 0.0, 'spammer': 0.1}, 'universal': {'astroturf': 0.3, 'fake_follower': 0.0, 'financial': 0.0, 'other': 0.0, 'overall': 0.2, 'self_declared': 0.0, 'spammer': 0.0}}, 'raw_scores': {'english': {'astroturf': 0.05, 'fake_follower': 0.05, 'financial': 0.0, 'other': 0.13, 'overall': 0.08, 'self_declared': 0.0, 'spammer': 0.02}, 'universal': {'astroturf': 0.06, 'fake_follower': 0.01, 'financial': 0.0, 'other': 0.01, 'overall': 0.03, 'self_declared': 0.0, 'spammer': 0.01}}, 'user': {'majority_lang': 'en', 'user_data': {'id_str': '3291688688', 'screen_name': 'DipayanDMR'}}}
# ======================= Evils_Paradise =======================
# {'cap': {'english': 0.621687023966582, 'universal': 0.7089830786080018}, 'display_scores': {'english': {'astroturf': 0.4, 'fake_follower': 0.8, 'financial': 0.4, 'other': 1.4, 'overall': 0.8, 'self_declared': 0.0, 'spammer': 0.5}, 'universal': {'astroturf': 0.4, 'fake_follower': 0.8, 'financial': 0.2, 'other': 1.2, 'overall': 1.0, 'self_declared': 0.0, 'spammer': 0.4}}, 'raw_scores': {'english': {'astroturf': 0.08, 'fake_follower': 0.15, 'financial': 0.09, 'other': 0.28, 'overall': 0.16, 'self_declared': 0.0, 'spammer': 0.1}, 'universal': {'astroturf': 0.08, 'fake_follower': 0.16, 'financial': 0.04, 'other': 0.24, 'overall': 0.2, 'self_declared': 0.0, 'spammer': 0.08}}, 'user': {'majority_lang': 'en', 'user_data': {'id_str': '1021012136221278211', 'screen_name': 'Evils_Paradise'}}}
# ======================= Bdjena988 =======================
# {'cap': {'english': 0.8036706514015852, 'universal': 0.8193478253485871}, 'display_scores': {'english': {'astroturf': 0.4, 'fake_follower': 1.6, 'financial': 0.5, 'other': 3.8, 'overall': 3.8, 'self_declared': 3.2, 'spammer': 0.8}, 'universal': {'astroturf': 0.6, 'fake_follower': 2.2, 'financial': 0.6, 'other': 4.0, 'overall': 4.0, 'self_declared': 3.6, 'spammer': 0.6}}, 'raw_scores': {'english': {'astroturf': 0.09, 'fake_follower': 0.33, 'financial': 0.1, 'other': 0.76, 'overall': 0.76, 'self_declared': 0.63, 'spammer': 0.15}, 'universal': {'astroturf': 0.13, 'fake_follower': 0.43, 'financial': 0.13, 'other': 0.8, 'overall': 0.8, 'self_declared': 0.73, 'spammer': 0.13}}, 'user': {'majority_lang': 'en', 'user_data': {'id_str': '1373322044616577024', 'screen_name': 'Bdjena988'}}}
# ======================= santuriju =======================
# {'cap': {'english': 0.7952555385005927, 'universal': 0.3469210182245441}, 'display_scores': {'english': {'astroturf': 0.2, 'fake_follower': 1.6, 'financial': 0.5, 'other': 2.9, 'overall': 2.0, 'self_declared': 0.0, 'spammer': 0.8}, 'universal': {'astroturf': 0.2, 'fake_follower': 0.6, 'financial': 0.2, 'other': 0.5, 'overall': 0.2, 'self_declared': 0.0, 'spammer': 0.0}}, 'raw_scores': {'english': {'astroturf': 0.03, 'fake_follower': 0.32, 'financial': 0.1, 'other': 0.58, 'overall': 0.41, 'self_declared': 0.0, 'spammer': 0.16}, 'universal': {'astroturf': 0.04, 'fake_follower': 0.11, 'financial': 0.03, 'other': 0.1, 'overall': 0.05, 'self_declared': 0.0, 'spammer': 0.01}}, 'user': {'majority_lang': 'hi', 'user_data': {'id_str': '1030187837612732417', 'screen_name': 'santuriju'}}}
# ======================= thejendra =======================
# {'cap': {'english': 0.7717813288270262, 'universal': 0.8006881983123656}, 'display_scores': {'english': {'astroturf': 0.8, 'fake_follower': 0.3, 'financial': 0.0, 'other': 1.4, 'overall': 1.4, 'self_declared': 0.0, 'spammer': 0.0}, 'universal': {'astroturf': 0.8, 'fake_follower': 0.2, 'financial': 0.0, 'other': 1.7, 'overall': 1.8, 'self_declared': 0.0, 'spammer': 0.0}}, 'raw_scores': {'english': {'astroturf': 0.15, 'fake_follower': 0.06, 'financial': 0.0, 'other': 0.28, 'overall': 0.29, 'self_declared': 0.01, 'spammer': 0.0}, 'universal': {'astroturf': 0.16, 'fake_follower': 0.05, 'financial': 0.0, 'other': 0.34, 'overall': 0.37, 'self_declared': 0.01, 'spammer': 0.0}}, 'user': {'majority_lang': 'en', 'user_data': {'id_str': '37661820', 'screen_name': 'thejendra'}}}
# ======================= Prasenjit97m =======================
# {'error': "TweepError: [{'code': 34, 'message': 'Sorry, that page does not exist.'}]"}
# ======================= Prasenjit97m =======================
# {'error': "TweepError: [{'code': 34, 'message': 'Sorry, that page does not exist.'}]"}
# ======================= zab_khan92 =======================
# {'cap': {'english': 0.6915799517497913, 'universal': 0.5488888157824968}, 'display_scores': {'english': {'astroturf': 0.2, 'fake_follower': 1.0, 'financial': 0.2, 'other': 1.4, 'overall': 1.0, 'self_declared': 0.0, 'spammer': 0.0}, 'universal': {'astroturf': 0.3, 'fake_follower': 0.9, 'financial': 0.0, 'other': 0.6, 'overall': 0.6, 'self_declared': 0.0, 'spammer': 0.0}}, 'raw_scores': {'english': {'astroturf': 0.04, 'fake_follower': 0.21, 'financial': 0.03, 'other': 0.27, 'overall': 0.2, 'self_declared': 0.0, 'spammer': 0.0}, 'universal': {'astroturf': 0.06, 'fake_follower': 0.18, 'financial': 0.0, 'other': 0.13, 'overall': 0.12, 'self_declared': 0.0, 'spammer': 0.01}}, 'user': {'majority_lang': 'en', 'user_data': {'id_str': '1082524978292146177', 'screen_name': 'zab_khan92'}}}
# ======================= Aishwaryarbagla =======================
# {'cap': {'english': 0.4479465575931997, 'universal': 0.28846389695411967}, 'display_scores': {'english': {'astroturf': 0.4, 'fake_follower': 0.6, 'financial': 0.4, 'other': 0.6, 'overall': 0.4, 'self_declared': 0.0, 'spammer': 0.0}, 'universal': {'astroturf': 0.6, 'fake_follower': 0.2, 'financial': 0.2, 'other': 0.8, 'overall': 0.2, 'self_declared': 0.0, 'spammer': 0.0}}, 'raw_scores': {'english': {'astroturf': 0.08, 'fake_follower': 0.12, 'financial': 0.07, 'other': 0.12, 'overall': 0.09, 'self_declared': 0.0, 'spammer': 0.0}, 'universal': {'astroturf': 0.11, 'fake_follower': 0.05, 'financial': 0.04, 'other': 0.16, 'overall': 0.03, 'self_declared': 0.0, 'spammer': 0.0}}, 'user': {'majority_lang': 'en', 'user_data': {'id_str': '98797649', 'screen_name': 'Aishwaryarbagla'}}}
# ======================= Sreedha24324771 =======================
# {'cap': {'english': 0.7546218700467833, 'universal': 0.7437205366967014}, 'display_scores': {'english': {'astroturf': 1.0, 'fake_follower': 0.4, 'financial': 0.0, 'other': 1.4, 'overall': 1.3, 'self_declared': 0.1, 'spammer': 0.6}, 'universal': {'astroturf': 0.6, 'fake_follower': 0.9, 'financial': 0.0, 'other': 1.4, 'overall': 1.2, 'self_declared': 0.0, 'spammer': 0.6}}, 'raw_scores': {'english': {'astroturf': 0.2, 'fake_follower': 0.07, 'financial': 0.01, 'other': 0.28, 'overall': 0.26, 'self_declared': 0.02, 'spammer': 0.11}, 'universal': {'astroturf': 0.12, 'fake_follower': 0.18, 'financial': 0.01, 'other': 0.29, 'overall': 0.23, 'self_declared': 0.01, 'spammer': 0.13}}, 'user': {'majority_lang': 'en', 'user_data': {'id_str': '1426512395485253634', 'screen_name': 'Sreedha24324771'}}}
# ======================= maverick9762 =======================
# {'error': 'TweepError: Not authorized.'}
# ======================= frankblunt2021 =======================
# {'error': "TweepError: [{'code': 34, 'message': 'Sorry, that page does not exist.'}]"}
# ======================= nkagr2706 =======================
# {'cap': {'english': 0.7611878625273879, 'universal': 0.5222398722127631}, 'display_scores': {'english': {'astroturf': 0.8, 'fake_follower': 0.8, 'financial': 0.8, 'other': 1.6, 'overall': 1.4, 'self_declared': 0.0, 'spammer': 0.1}, 'universal': {'astroturf': 0.6, 'fake_follower': 0.3, 'financial': 0.2, 'other': 0.7, 'overall': 0.6, 'self_declared': 0.0, 'spammer': 0.0}}, 'raw_scores': {'english': {'astroturf': 0.17, 'fake_follower': 0.16, 'financial': 0.15, 'other': 0.32, 'overall': 0.27, 'self_declared': 0.01, 'spammer': 0.02}, 'universal': {'astroturf': 0.11, 'fake_follower': 0.06, 'financial': 0.03, 'other': 0.14, 'overall': 0.11, 'self_declared': 0.01, 'spammer': 0.01}}, 'user': {'majority_lang': 'hi', 'user_data': {'id_str': '2477766036', 'screen_name': 'nkagr2706'}}}
# ======================= vjv02 =======================
# {'cap': {'english': 0.30618807248975083, 'universal': 0.37678996390568303}, 'display_scores': {'english': {'astroturf': 1.0, 'fake_follower': 0.4, 'financial': 0.0, 'other': 1.4, 'overall': 0.2, 'self_declared': 0.4, 'spammer': 0.0}, 'universal': {'astroturf': 0.6, 'fake_follower': 0.5, 'financial': 0.0, 'other': 1.5, 'overall': 0.3, 'self_declared': 0.0, 'spammer': 0.2}}, 'raw_scores': {'english': {'astroturf': 0.19, 'fake_follower': 0.09, 'financial': 0.0, 'other': 0.29, 'overall': 0.04, 'self_declared': 0.07, 'spammer': 0.0}, 'universal': {'astroturf': 0.13, 'fake_follower': 0.1, 'financial': 0.0, 'other': 0.3, 'overall': 0.06, 'self_declared': 0.01, 'spammer': 0.03}}, 'user': {'majority_lang': 'en', 'user_data': {'id_str': '2933791980', 'screen_name': 'vjv02'}}}
# ======================= SamsulH40825884 =======================
# {'cap': {'english': 0.7939576449836836, 'universal': 0.3469210182245441}, 'display_scores': {'english': {'astroturf': 0.7, 'fake_follower': 1.6, 'financial': 0.2, 'other': 1.6, 'overall': 2.0, 'self_declared': 0.0, 'spammer': 0.6}, 'universal': {'astroturf': 0.4, 'fake_follower': 1.3, 'financial': 0.0, 'other': 0.9, 'overall': 0.2, 'self_declared': 0.0, 'spammer': 0.2}}, 'raw_scores': {'english': {'astroturf': 0.14, 'fake_follower': 0.31, 'financial': 0.05, 'other': 0.31, 'overall': 0.39, 'self_declared': 0.01, 'spammer': 0.11}, 'universal': {'astroturf': 0.08, 'fake_follower': 0.26, 'financial': 0.01, 'other': 0.18, 'overall': 0.05, 'self_declared': 0.0, 'spammer': 0.03}}, 'user': {'majority_lang': 'en', 'user_data': {'id_str': '983709188919476224', 'screen_name': 'SamsulH40825884'}}}
# ======================= SamsulH40825884 =======================
# {'cap': {'english': 0.7939576449836836, 'universal': 0.3469210182245441}, 'display_scores': {'english': {'astroturf': 0.7, 'fake_follower': 1.6, 'financial': 0.2, 'other': 1.6, 'overall': 2.0, 'self_declared': 0.0, 'spammer': 0.6}, 'universal': {'astroturf': 0.4, 'fake_follower': 1.3, 'financial': 0.0, 'other': 0.9, 'overall': 0.2, 'self_declared': 0.0, 'spammer': 0.2}}, 'raw_scores': {'english': {'astroturf': 0.14, 'fake_follower': 0.31, 'financial': 0.05, 'other': 0.31, 'overall': 0.39, 'self_declared': 0.01, 'spammer': 0.11}, 'universal': {'astroturf': 0.08, 'fake_follower': 0.26, 'financial': 0.01, 'other': 0.18, 'overall': 0.05, 'self_declared': 0.0, 'spammer': 0.03}}, 'user': {'majority_lang': 'en', 'user_data': {'id_str': '983709188919476224', 'screen_name': 'SamsulH40825884'}}}
# ======================= KumarPangolin =======================
# {'cap': {'english': 0.659646495284545, 'universal': 0.7865642668428161}, 'display_scores': {'english': {'astroturf': 0.4, 'fake_follower': 1.0, 'financial': 0.2, 'other': 0.4, 'overall': 0.9, 'self_declared': 0.1, 'spammer': 0.2}, 'universal': {'astroturf': 1.0, 'fake_follower': 0.8, 'financial': 0.4, 'other': 0.5, 'overall': 1.5, 'self_declared': 0.0, 'spammer': 0.6}}, 'raw_scores': {'english': {'astroturf': 0.08, 'fake_follower': 0.2, 'financial': 0.05, 'other': 0.07, 'overall': 0.18, 'self_declared': 0.02, 'spammer': 0.03}, 'universal': {'astroturf': 0.21, 'fake_follower': 0.16, 'financial': 0.08, 'other': 0.1, 'overall': 0.3, 'self_declared': 0.01, 'spammer': 0.11}}, 'user': {'majority_lang': 'en', 'user_data': {'id_str': '1532395587488088064', 'screen_name': 'KumarPangolin'}}}
# ======================= hhmollick =======================
# {'cap': {'english': 0.7717813288270262, 'universal': 0.5488888157824968}, 'display_scores': {'english': {'astroturf': 1.6, 'fake_follower': 0.9, 'financial': 0.0, 'other': 1.9, 'overall': 1.4, 'self_declared': 0.0, 'spammer': 0.1}, 'universal': {'astroturf': 1.6, 'fake_follower': 0.6, 'financial': 0.0, 'other': 1.2, 'overall': 0.6, 'self_declared': 0.0, 'spammer': 0.0}}, 'raw_scores': {'english': {'astroturf': 0.33, 'fake_follower': 0.18, 'financial': 0.0, 'other': 0.38, 'overall': 0.29, 'self_declared': 0.0, 'spammer': 0.02}, 'universal': {'astroturf': 0.33, 'fake_follower': 0.12, 'financial': 0.01, 'other': 0.25, 'overall': 0.12, 'self_declared': 0.0, 'spammer': 0.0}}, 'user': {'majority_lang': 'en', 'user_data': {'id_str': '3309971509', 'screen_name': 'hhmollick'}}}
# ======================= FaridAnsari0786 =======================
# {'cap': {'english': 0.7966668301280437, 'universal': 0.7947108099739177}, 'display_scores': {'english': {'astroturf': 0.4, 'fake_follower': 2.2, 'financial': 0.3, 'other': 3.0, 'overall': 3.0, 'self_declared': 0.1, 'spammer': 1.0}, 'universal': {'astroturf': 0.4, 'fake_follower': 1.7, 'financial': 0.2, 'other': 1.8, 'overall': 1.6, 'self_declared': 0.0, 'spammer': 0.4}}, 'raw_scores': {'english': {'astroturf': 0.08, 'fake_follower': 0.44, 'financial': 0.06, 'other': 0.61, 'overall': 0.61, 'self_declared': 0.02, 'spammer': 0.2}, 'universal': {'astroturf': 0.07, 'fake_follower': 0.34, 'financial': 0.04, 'other': 0.37, 'overall': 0.33, 'self_declared': 0.0, 'spammer': 0.09}}, 'user': {'majority_lang': 'hi', 'user_data': {'id_str': '1309468126812266499', 'screen_name': 'FaridAnsari0786'}}}
# ======================= FaridAnsari0786 =======================
# {'cap': {'english': 0.7966668301280437, 'universal': 0.7947108099739177}, 'display_scores': {'english': {'astroturf': 0.4, 'fake_follower': 2.2, 'financial': 0.3, 'other': 3.0, 'overall': 3.0, 'self_declared': 0.1, 'spammer': 1.0}, 'universal': {'astroturf': 0.4, 'fake_follower': 1.7, 'financial': 0.2, 'other': 1.8, 'overall': 1.6, 'self_declared': 0.0, 'spammer': 0.4}}, 'raw_scores': {'english': {'astroturf': 0.08, 'fake_follower': 0.44, 'financial': 0.06, 'other': 0.61, 'overall': 0.61, 'self_declared': 0.02, 'spammer': 0.2}, 'universal': {'astroturf': 0.07, 'fake_follower': 0.34, 'financial': 0.04, 'other': 0.37, 'overall': 0.33, 'self_declared': 0.0, 'spammer': 0.09}}, 'user': {'majority_lang': 'hi', 'user_data': {'id_str': '1309468126812266499', 'screen_name': 'FaridAnsari0786'}}}
# ======================= bitmasti =======================
# {'cap': {'english': 0.7946723107742963, 'universal': 0.7982287282125168}, 'display_scores': {'english': {'astroturf': 1.2, 'fake_follower': 0.6, 'financial': 0.0, 'other': 2.4, 'overall': 2.0, 'self_declared': 0.0, 'spammer': 0.4}, 'universal': {'astroturf': 1.2, 'fake_follower': 0.6, 'financial': 0.0, 'other': 0.9, 'overall': 1.8, 'self_declared': 0.0, 'spammer': 0.4}}, 'raw_scores': {'english': {'astroturf': 0.24, 'fake_follower': 0.11, 'financial': 0.0, 'other': 0.49, 'overall': 0.4, 'self_declared': 0.0, 'spammer': 0.07}, 'universal': {'astroturf': 0.24, 'fake_follower': 0.11, 'financial': 0.01, 'other': 0.18, 'overall': 0.35, 'self_declared': 0.01, 'spammer': 0.08}}, 'user': {'majority_lang': 'hi', 'user_data': {'id_str': '1479452717223456768', 'screen_name': 'bitmasti'}}}

# %% [markdown]
# ### Extract specific Botometer scores for the list of usernames

# %% [markdown]
# Function to return specific output scores as lists

# %%
def forward (username_list):

  cap_english = []
  cap_universal = []

  overall_raw_score_eng = []
  overall_raw_score_universal = []

  overall_display_score_eng = []
  overall_display_score_universal = []

  for account_name, result in bom.check_accounts_in (username_list):

    #if (account_name=='spandakarika108' or account_name=='Prasenjit97m' or account_name=='bhattketan1468' or account_name=='Hilale_pakistan'):
    if (account_name=='mrImteyaz8' or account_name=='Notsoyoung5' or account_name=='dinakar24' or account_name=='Prasenjit97m' or account_name=='jainarahari108' or account_name=='maverick9762' or account_name=='TheWhiteWaIker' or account_name=='frankblunt2021'):
      cap_english.append (0)
      cap_universal.append (0)
      overall_raw_score_eng.append (0)
      overall_raw_score_universal.append (0)
      overall_display_score_eng.append (0)
      overall_display_score_universal.append (0)

    else:
    
      print ("=======================", account_name, "=======================")
    
      print_scores (result)
    
      scores = extract_scores (result)

      cap_english.append (scores[0])
      cap_universal.append (scores[1])

      overall_raw_score_eng.append (scores[2])
      overall_raw_score_universal.append (scores[3])

      overall_display_score_eng.append (scores[4])
      overall_display_score_universal.append (scores[5])

  return (cap_english, 
          cap_universal, 
          overall_raw_score_eng,
          overall_raw_score_universal,
          overall_display_score_eng,
          overall_display_score_universal)

# %% [markdown]
# Run the forward function

# %%
(cap_english_list, 
 cap_universal_list, 
 overall_raw_score_eng_list, 
 overall_raw_score_universal_list, 
 overall_display_score_eng_list, 
 overall_display_score_universal_list) = forward (username_list)
# Out:
# ======================= Nmenon777 =======================
# --- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---
# Cap in English: 0.4479465575931997
# Cap in Universal: 0.3469210182245441
# --- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---
# Overall raw score in English: 0.09
# Overall raw score in Universal: 0.05
# --- Display scores: same as raw scores, but in the [0,5] range ---
# Overall display score in English: 0.4
# Overall display score in Universal: 0.2
# ======================= AteequeKLD =======================
# --- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---
# Cap in English: 0.8395863545645614
# Cap in Universal: 0.8054092120440788
# --- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---
# Overall raw score in English: 0.86
# Overall raw score in Universal: 0.66
# --- Display scores: same as raw scores, but in the [0,5] range ---
# Overall display score in English: 4.3
# Overall display score in Universal: 3.3
# ======================= CoolHugs_ =======================
# --- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---
# Cap in English: 0.7852210697594887
# Cap in Universal: 0.7089830786080018
# --- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---
# Overall raw score in English: 0.33
# Overall raw score in Universal: 0.2
# --- Display scores: same as raw scores, but in the [0,5] range ---
# Overall display score in English: 1.6
# Overall display score in Universal: 1.0
# ======================= ICIMonline =======================
# --- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---
# Cap in English: 0.7965971518887632
# Cap in Universal: 0.8053787930995948
# --- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---
# Overall raw score in English: 0.63
# Overall raw score in Universal: 0.5
# --- Display scores: same as raw scores, but in the [0,5] range ---
# Overall display score in English: 3.2
# Overall display score in Universal: 2.5
# ======================= mudde_rama =======================
# --- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---
# Cap in English: 0.6414184221423734
# Cap in Universal: 0.4658392474232361
# --- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---
# Overall raw score in English: 0.17
# Overall raw score in Universal: 0.09
# --- Display scores: same as raw scores, but in the [0,5] range ---
# Overall display score in English: 0.8
# Overall display score in Universal: 0.4
# ======================= MuhammadXunaid0 =======================
# --- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---
# Cap in English: 0.7611878625273879
# Cap in Universal: 0.5488888157824968
# --- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---
# Overall raw score in English: 0.27
# Overall raw score in Universal: 0.12
# --- Display scores: same as raw scores, but in the [0,5] range ---
# Overall display score in English: 1.4
# Overall display score in Universal: 0.6
# ======================= shahruk92461711 =======================
# --- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---
# Cap in English: 0.8748575042966269
# Cap in Universal: 0.8082278383974655
# --- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---
# Overall raw score in English: 0.91
# Overall raw score in Universal: 0.73
# --- Display scores: same as raw scores, but in the [0,5] range ---
# Overall display score in English: 4.6
# Overall display score in Universal: 3.6
# ======================= abdullahsir36 =======================
# --- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---
# Cap in English: 0.6915799517497913
# Cap in Universal: 0.4658392474232361
# --- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---
# Overall raw score in English: 0.2
# Overall raw score in Universal: 0.09
# --- Display scores: same as raw scores, but in the [0,5] range ---
# Overall display score in English: 1.0
# Overall display score in Universal: 0.4
# ======================= Kaavi2021 =======================
# --- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---
# Cap in English: 0.7470839770895665
# Cap in Universal: 0.8006881983123656
# --- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---
# Overall raw score in English: 0.25
# Overall raw score in Universal: 0.37
# --- Display scores: same as raw scores, but in the [0,5] range ---
# Overall display score in English: 1.2
# Overall display score in Universal: 1.8
# ======================= CHILLPI25037592 =======================
# --- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---
# Cap in English: 0.7920317685697057
# Cap in Universal: 0.7828265255249504
# --- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---
# Overall raw score in English: 0.37
# Overall raw score in Universal: 0.29
# --- Display scores: same as raw scores, but in the [0,5] range ---
# Overall display score in English: 1.8
# Overall display score in Universal: 1.4
# ======================= ProudIndian_253 =======================
# --- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---
# Cap in English: 0.7470839770895665
# Cap in Universal: 0.7733457112766196
# --- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---
# Overall raw score in English: 0.25
# Overall raw score in Universal: 0.27
# --- Display scores: same as raw scores, but in the [0,5] range ---
# Overall display score in English: 1.2
# Overall display score in Universal: 1.4
# ======================= Hashimalhanfi =======================
# --- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---
# Cap in English: 0.7968599400514179
# Cap in Universal: 0.7947108099739177
# --- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---
# Overall raw score in English: 0.58
# Overall raw score in Universal: 0.33
# --- Display scores: same as raw scores, but in the [0,5] range ---
# Overall display score in English: 2.9
# Overall display score in Universal: 1.6
# ======================= KMortha =======================
# --- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---
# Cap in English: 0.6414184221423734
# Cap in Universal: 0.31739450135566455
# --- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---
# Overall raw score in English: 0.17
# Overall raw score in Universal: 0.04
# --- Display scores: same as raw scores, but in the [0,5] range ---
# Overall display score in English: 0.8
# Overall display score in Universal: 0.2
# ======================= ProudIndian_253 =======================
# --- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---
# Cap in English: 0.7470839770895665
# Cap in Universal: 0.7733457112766196
# --- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---
# Overall raw score in English: 0.25
# Overall raw score in Universal: 0.27
# --- Display scores: same as raw scores, but in the [0,5] range ---
# Overall display score in English: 1.2
# Overall display score in Universal: 1.4
# ======================= chandrats06 =======================
# --- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---
# Cap in English: 0.5027122940873614
# Cap in Universal: 0.6945161422354588
# --- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---
# Overall raw score in English: 0.11
# Overall raw score in Universal: 0.19
# --- Display scores: same as raw scores, but in the [0,5] range ---
# Overall display score in English: 0.6
# Overall display score in Universal: 1.0
# ======================= lemonchusleee =======================
# --- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---
# Cap in English: 0.7966668301280437
# Cap in Universal: 0.7527121552274618
# --- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---
# Overall raw score in English: 0.61
# Overall raw score in Universal: 0.24
# --- Display scores: same as raw scores, but in the [0,5] range ---
# Overall display score in English: 3.0
# Overall display score in Universal: 1.2
# ======================= zubair7409 =======================
# --- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---
# Cap in English: 0.7759887465100499
# Cap in Universal: 0.4658392474232361
# --- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---
# Overall raw score in English: 0.3
# Overall raw score in Universal: 0.09
# --- Display scores: same as raw scores, but in the [0,5] range ---
# Overall display score in English: 1.5
# Overall display score in Universal: 0.4
# ======================= Md35556134 =======================
# --- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---
# Cap in English: 0.7759887465100499
# Cap in Universal: 0.7089830786080018
# --- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---
# Overall raw score in English: 0.3
# Overall raw score in Universal: 0.2
# --- Display scores: same as raw scores, but in the [0,5] range ---
# Overall display score in English: 1.5
# Overall display score in Universal: 1.0
# ======================= Sreedha24324771 =======================
# --- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---
# Cap in English: 0.7668769621923945
# Cap in Universal: 0.7733457112766196
# --- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---
# Overall raw score in English: 0.28
# Overall raw score in Universal: 0.27
# --- Display scores: same as raw scores, but in the [0,5] range ---
# Overall display score in English: 1.4
# Overall display score in Universal: 1.4
# ======================= Iamraje78412219 =======================
# --- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---
# Cap in English: 0.7874002196908744
# Cap in Universal: 0.8035432096295109
# --- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---
# Overall raw score in English: 0.34
# Overall raw score in Universal: 0.41
# --- Display scores: same as raw scores, but in the [0,5] range ---
# Overall display score in English: 1.7
# Overall display score in Universal: 2.0
# ======================= Shaikhm04230983 =======================
# --- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---
# Cap in English: 0.7759887465100499
# Cap in Universal: 0.5222398722127631
# --- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---
# Overall raw score in English: 0.3
# Overall raw score in Universal: 0.11
# --- Display scores: same as raw scores, but in the [0,5] range ---
# Overall display score in English: 1.5
# Overall display score in Universal: 0.6
# ======================= cricketspr =======================
# --- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---
# Cap in English: 0.7983123643488195
# Cap in Universal: 0.8091273704655436
# --- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---
# Overall raw score in English: 0.71
# Overall raw score in Universal: 0.74
# --- Display scores: same as raw scores, but in the [0,5] range ---
# Overall display score in English: 3.6
# Overall display score in Universal: 3.7
# ======================= yaji63 =======================
# --- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---
# Cap in English: 0.779581525363529
# Cap in Universal: 0.792436790569533
# --- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---
# Overall raw score in English: 0.31
# Overall raw score in Universal: 0.32
# --- Display scores: same as raw scores, but in the [0,5] range ---
# Overall display score in English: 1.6
# Overall display score in Universal: 1.6
# ======================= SkSuhael =======================
# --- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---
# Cap in English: 0.7826357858330618
# Cap in Universal: 0.6784864269642225
# --- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---
# Overall raw score in English: 0.32
# Overall raw score in Universal: 0.18
# --- Display scores: same as raw scores, but in the [0,5] range ---
# Overall display score in English: 1.6
# Overall display score in Universal: 0.9
# ======================= ehram123 =======================
# --- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---
# Cap in English: 0.5288664776112156
# Cap in Universal: 0.37678996390568303
# --- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---
# Overall raw score in English: 0.12
# Overall raw score in Universal: 0.06
# --- Display scores: same as raw scores, but in the [0,5] range ---
# Overall display score in English: 0.6
# Overall display score in Universal: 0.3
# ======================= _irrationality0 =======================
# --- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---
# Cap in English: 0.7759887465100499
# Cap in Universal: 0.8030212452554465
# --- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---
# Overall raw score in English: 0.3
# Overall raw score in Universal: 0.4
# --- Display scores: same as raw scores, but in the [0,5] range ---
# Overall display score in English: 1.5
# Overall display score in Universal: 2.0
# ======================= tradingfutures1 =======================
# --- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---
# Cap in English: 0.7384783166429812
# Cap in Universal: 0.37678996390568303
# --- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---
# Overall raw score in English: 0.24
# Overall raw score in Universal: 0.06
# --- Display scores: same as raw scores, but in the [0,5] range ---
# Overall display score in English: 1.2
# Overall display score in Universal: 0.3
# ======================= SankarsanBarik4 =======================
# --- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---
# Cap in English: 0.6004883262510591
# Cap in Universal: 0.5222398722127631
# --- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---
# Overall raw score in English: 0.15
# Overall raw score in Universal: 0.11
# --- Display scores: same as raw scores, but in the [0,5] range ---
# Overall display score in English: 0.8
# Overall display score in Universal: 0.6
# ======================= TarunKGupta2 =======================
# --- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---
# Cap in English: 0.6004883262510591
# Cap in Universal: 0.5488888157824968
# --- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---
# Overall raw score in English: 0.15
# Overall raw score in Universal: 0.12
# --- Display scores: same as raw scores, but in the [0,5] range ---
# Overall display score in English: 0.8
# Overall display score in Universal: 0.6
# ======================= canarayan1 =======================
# --- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---
# Cap in English: 0.797075908158591
# Cap in Universal: 0.8068955728616037
# --- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---
# Overall raw score in English: 0.68
# Overall raw score in Universal: 0.71
# --- Display scores: same as raw scores, but in the [0,5] range ---
# Overall display score in English: 3.4
# Overall display score in Universal: 3.6
# ======================= KiranKumarGK1 =======================
# --- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---
# Cap in English: 0.8670116134145492
# Cap in Universal: 0.8372129323854712
# --- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---
# Overall raw score in English: 0.9
# Overall raw score in Universal: 0.85
# --- Display scores: same as raw scores, but in the [0,5] range ---
# Overall display score in English: 4.5
# Overall display score in Universal: 4.2
# ======================= Avijit3k2 =======================
# --- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---
# Cap in English: 0.36264564124632276
# Cap in Universal: 0.4658392474232361
# --- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---
# Overall raw score in English: 0.06
# Overall raw score in Universal: 0.09
# --- Display scores: same as raw scores, but in the [0,5] range ---
# Overall display score in English: 0.3
# Overall display score in Universal: 0.4
# ======================= ramanvk819 =======================
# --- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---
# Cap in English: 0.6915799517497913
# Cap in Universal: 0.6415870166679795
# --- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---
# Overall raw score in English: 0.2
# Overall raw score in Universal: 0.16
# --- Display scores: same as raw scores, but in the [0,5] range ---
# Overall display score in English: 1.0
# Overall display score in Universal: 0.8
# ======================= Pj_Keshriyagrp =======================
# --- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---
# Cap in English: 0.4197222421546159
# Cap in Universal: 0.37678996390568303
# --- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---
# Overall raw score in English: 0.08
# Overall raw score in Universal: 0.06
# --- Display scores: same as raw scores, but in the [0,5] range ---
# Overall display score in English: 0.4
# Overall display score in Universal: 0.3
# ======================= JaiPoori =======================
# --- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---
# Cap in English: 0.7546218700467833
# Cap in Universal: 0.5488888157824968
# --- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---
# Overall raw score in English: 0.26
# Overall raw score in Universal: 0.12
# --- Display scores: same as raw scores, but in the [0,5] range ---
# Overall display score in English: 1.3
# Overall display score in Universal: 0.6
# ======================= aamehta1980 =======================
# --- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---
# Cap in English: 0.7717813288270262
# Cap in Universal: 0.6608500314332488
# --- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---
# Overall raw score in English: 0.29
# Overall raw score in Universal: 0.17
# --- Display scores: same as raw scores, but in the [0,5] range ---
# Overall display score in English: 1.4
# Overall display score in Universal: 0.8
# ======================= Subash37006856 =======================
# --- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---
# Cap in English: 0.2787259978325127
# Cap in Universal: 0.28846389695411967
# --- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---
# Overall raw score in English: 0.03
# Overall raw score in Universal: 0.03
# --- Display scores: same as raw scores, but in the [0,5] range ---
# Overall display score in English: 0.2
# Overall display score in Universal: 0.2
# ======================= underpaidsevak =======================
# --- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---
# Cap in English: 0.6414184221423734
# Cap in Universal: 0.792436790569533
# --- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---
# Overall raw score in English: 0.17
# Overall raw score in Universal: 0.32
# --- Display scores: same as raw scores, but in the [0,5] range ---
# Overall display score in English: 0.8
# Overall display score in Universal: 1.6
# ======================= Manishis050 =======================
# --- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---
# Cap in English: 0.796599114745521
# Cap in Universal: 0.7947108099739177
# --- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---
# Overall raw score in English: 0.64
# Overall raw score in Universal: 0.33
# --- Display scores: same as raw scores, but in the [0,5] range ---
# Overall display score in English: 3.2
# Overall display score in Universal: 1.6
# ======================= NikhilRaod =======================
# --- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---
# Cap in English: 0.6915799517497913
# Cap in Universal: 0.760577756485164
# --- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---
# Overall raw score in English: 0.2
# Overall raw score in Universal: 0.25
# --- Display scores: same as raw scores, but in the [0,5] range ---
# Overall display score in English: 1.0
# Overall display score in Universal: 1.2
# ======================= asifmohd63 =======================
# --- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---
# Cap in English: 0.7907586934369296
# Cap in Universal: 0.3469210182245441
# --- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---
# Overall raw score in English: 0.36
# Overall raw score in Universal: 0.05
# --- Display scores: same as raw scores, but in the [0,5] range ---
# Overall display score in English: 1.8
# Overall display score in Universal: 0.2
# ======================= ra54077891 =======================
# --- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---
# Cap in English: 0.8995513244218455
# Cap in Universal: 0.9121502174127201
# --- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---
# Overall raw score in English: 0.94
# Overall raw score in Universal: 0.96
# --- Display scores: same as raw scores, but in the [0,5] range ---
# Overall display score in English: 4.7
# Overall display score in Universal: 4.8
# ======================= rajarshi_sg =======================
# --- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---
# Cap in English: 0.7967206940193189
# Cap in Universal: 0.801617083559931
# --- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---
# Overall raw score in English: 0.66
# Overall raw score in Universal: 0.38
# --- Display scores: same as raw scores, but in the [0,5] range ---
# Overall display score in English: 3.3
# Overall display score in Universal: 1.9
# ======================= MaskMan17122213 =======================
# --- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---
# Cap in English: 0.7920317685697057
# Cap in Universal: 0.49449072748283696
# --- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---
# Overall raw score in English: 0.37
# Overall raw score in Universal: 0.1
# --- Display scores: same as raw scores, but in the [0,5] range ---
# Overall display score in English: 1.8
# Overall display score in Universal: 0.5
# ======================= Sid95879 =======================
# --- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---
# Cap in English: 0.621687023966582
# Cap in Universal: 0.43650814830094437
# --- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---
# Overall raw score in English: 0.16
# Overall raw score in Universal: 0.08
# --- Display scores: same as raw scores, but in the [0,5] range ---
# Overall display score in English: 0.8
# Overall display score in Universal: 0.4
# ======================= anbokshi =======================
# --- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---
# Cap in English: 0.7852210697594887
# Cap in Universal: 0.6415870166679795
# --- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---
# Overall raw score in English: 0.33
# Overall raw score in Universal: 0.16
# --- Display scores: same as raw scores, but in the [0,5] range ---
# Overall display score in English: 1.6
# Overall display score in Universal: 0.8
# ======================= dryahyakazi =======================
# --- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---
# Cap in English: 0.7892294694438972
# Cap in Universal: 0.4658392474232361
# --- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---
# Overall raw score in English: 0.35
# Overall raw score in Universal: 0.09
# --- Display scores: same as raw scores, but in the [0,5] range ---
# Overall display score in English: 1.8
# Overall display score in Universal: 0.4
# ======================= shanthala_kumar =======================
# --- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---
# Cap in English: 0.6763619064808265
# Cap in Universal: 0.49449072748283696
# --- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---
# Overall raw score in English: 0.19
# Overall raw score in Universal: 0.1
# --- Display scores: same as raw scores, but in the [0,5] range ---
# Overall display score in English: 1.0
# Overall display score in Universal: 0.5
# ======================= Shweta_India =======================
# --- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---
# Cap in English: 0.3342309004634953
# Cap in Universal: 0.43650814830094437
# --- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---
# Overall raw score in English: 0.05
# Overall raw score in Universal: 0.08
# --- Display scores: same as raw scores, but in the [0,5] range ---
# Overall display score in English: 0.2
# Overall display score in Universal: 0.4
# ======================= Srikarch11 =======================
# --- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---
# Cap in English: 0.7952555385005927
# Cap in Universal: 0.8043181589918191
# --- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---
# Overall raw score in English: 0.41
# Overall raw score in Universal: 0.43
# --- Display scores: same as raw scores, but in the [0,5] range ---
# Overall display score in English: 2.0
# Overall display score in Universal: 2.2
# ======================= Namami_Ganga =======================
# --- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---
# Cap in English: 0.7053377817049258
# Cap in Universal: 0.49449072748283696
# --- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---
# Overall raw score in English: 0.21
# Overall raw score in Universal: 0.1
# --- Display scores: same as raw scores, but in the [0,5] range ---
# Overall display score in English: 1.0
# Overall display score in Universal: 0.5
# ======================= Lisali89880277 =======================
# --- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---
# Cap in English: 0.8595061719862279
# Cap in Universal: 0.8885263643630983
# --- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---
# Overall raw score in English: 0.89
# Overall raw score in Universal: 0.93
# --- Display scores: same as raw scores, but in the [0,5] range ---
# Overall display score in English: 4.4
# Overall display score in Universal: 4.6
# ======================= funnyface234 =======================
# --- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---
# Cap in English: 0.797075908158591
# Cap in Universal: 0.8102129289660348
# --- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---
# Overall raw score in English: 0.68
# Overall raw score in Universal: 0.75
# --- Display scores: same as raw scores, but in the [0,5] range ---
# Overall display score in English: 3.4
# Overall display score in Universal: 3.8
# ======================= wind_duo =======================
# --- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---
# Cap in English: 0.4479465575931997
# Cap in Universal: 0.6415870166679795
# --- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---
# Overall raw score in English: 0.09
# Overall raw score in Universal: 0.16
# --- Display scores: same as raw scores, but in the [0,5] range ---
# Overall display score in English: 0.4
# Overall display score in Universal: 0.8
# ======================= nayakSSekhar =======================
# --- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---
# Cap in English: 0.3912159239072283
# Cap in Universal: 0.5222398722127631
# --- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---
# Overall raw score in English: 0.07
# Overall raw score in Universal: 0.11
# --- Display scores: same as raw scores, but in the [0,5] range ---
# Overall display score in English: 0.4
# Overall display score in Universal: 0.6
# ======================= tuubol =======================
# --- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---
# Cap in English: 0.3912159239072283
# Cap in Universal: 0.23332432370635456
# --- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---
# Overall raw score in English: 0.07
# Overall raw score in Universal: 0.01
# --- Display scores: same as raw scores, but in the [0,5] range ---
# Overall display score in English: 0.4
# Overall display score in Universal: 0.0
# ======================= Sanju40382206 =======================
# --- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---
# Cap in English: 0.8457543526336647
# Cap in Universal: 0.8662905376040458
# --- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---
# Overall raw score in English: 0.87
# Overall raw score in Universal: 0.9
# --- Display scores: same as raw scores, but in the [0,5] range ---
# Overall display score in English: 4.4
# Overall display score in Universal: 4.5
# ======================= Udays73 =======================
# --- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---
# Cap in English: 0.7968624754031172
# Cap in Universal: 0.8193478253485871
# --- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---
# Overall raw score in English: 0.67
# Overall raw score in Universal: 0.8
# --- Display scores: same as raw scores, but in the [0,5] range ---
# Overall display score in English: 3.4
# Overall display score in Universal: 4.0
# ======================= Lakshmoji =======================
# --- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---
# Cap in English: 0.7759887465100499
# Cap in Universal: 0.760577756485164
# --- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---
# Overall raw score in English: 0.3
# Overall raw score in Universal: 0.25
# --- Display scores: same as raw scores, but in the [0,5] range ---
# Overall display score in English: 1.5
# Overall display score in Universal: 1.2
# ======================= ReddyR2D2 =======================
# --- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---
# Cap in English: 0.659646495284545
# Cap in Universal: 0.7527121552274618
# --- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---
# Overall raw score in English: 0.18
# Overall raw score in Universal: 0.24
# --- Display scores: same as raw scores, but in the [0,5] range ---
# Overall display score in English: 0.9
# Overall display score in Universal: 1.2
# ======================= ranveer2252 =======================
# --- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---
# Cap in English: 0.0
# Cap in Universal: 0.3469210182245441
# --- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---
# Overall raw score in English: 0.0
# Overall raw score in Universal: 0.05
# --- Display scores: same as raw scores, but in the [0,5] range ---
# Overall display score in English: 0.0
# Overall display score in Universal: 0.2
# ======================= nimminavya =======================
# --- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---
# Cap in English: 0.6414184221423734
# Cap in Universal: 0.6415870166679795
# --- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---
# Overall raw score in English: 0.17
# Overall raw score in Universal: 0.16
# --- Display scores: same as raw scores, but in the [0,5] range ---
# Overall display score in English: 0.8
# Overall display score in Universal: 0.8
# ======================= rajesh104 =======================
# --- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---
# Cap in English: 0.3912159239072283
# Cap in Universal: 0.5742686032713971
# --- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---
# Overall raw score in English: 0.07
# Overall raw score in Universal: 0.13
# --- Display scores: same as raw scores, but in the [0,5] range ---
# Overall display score in English: 0.4
# Overall display score in Universal: 0.6
# ======================= lonerangerin =======================
# --- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---
# Cap in English: 0.621687023966582
# Cap in Universal: 0.37678996390568303
# --- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---
# Overall raw score in English: 0.16
# Overall raw score in Universal: 0.06
# --- Display scores: same as raw scores, but in the [0,5] range ---
# Overall display score in English: 0.8
# Overall display score in Universal: 0.3
# ======================= ashwinpshenoy =======================
# --- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---
# Cap in English: 0.7384783166429812
# Cap in Universal: 0.5742686032713971
# --- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---
# Overall raw score in English: 0.24
# Overall raw score in Universal: 0.13
# --- Display scores: same as raw scores, but in the [0,5] range ---
# Overall display score in English: 1.2
# Overall display score in Universal: 0.6
# ======================= BabuRao_Deva =======================
# --- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---
# Cap in English: 0.7611878625273879
# Cap in Universal: 0.8052176344738626
# --- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---
# Overall raw score in English: 0.27
# Overall raw score in Universal: 0.63
# --- Display scores: same as raw scores, but in the [0,5] range ---
# Overall display score in English: 1.4
# Overall display score in Universal: 3.2
# ======================= HimalayasOuter =======================
# --- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---
# Cap in English: 0.7611878625273879
# Cap in Universal: 0.7865642668428161
# --- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---
# Overall raw score in English: 0.27
# Overall raw score in Universal: 0.3
# --- Display scores: same as raw scores, but in the [0,5] range ---
# Overall display score in English: 1.4
# Overall display score in Universal: 1.5
# ======================= kewal_negi =======================
# --- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---
# Cap in English: 0.797782173166965
# Cap in Universal: 0.7784494983408411
# --- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---
# Overall raw score in English: 0.7
# Overall raw score in Universal: 0.28
# --- Display scores: same as raw scores, but in the [0,5] range ---
# Overall display score in English: 3.5
# Overall display score in Universal: 1.4
# ======================= mvmm12 =======================
# --- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---
# Cap in English: 0.6414184221423734
# Cap in Universal: 0.49449072748283696
# --- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---
# Overall raw score in English: 0.17
# Overall raw score in Universal: 0.1
# --- Display scores: same as raw scores, but in the [0,5] range ---
# Overall display score in English: 0.8
# Overall display score in Universal: 0.5
# ======================= Virampampaniya4 =======================
# --- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---
# Cap in English: 0.7176911080698488
# Cap in Universal: 0.37678996390568303
# --- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---
# Overall raw score in English: 0.22
# Overall raw score in Universal: 0.06
# --- Display scores: same as raw scores, but in the [0,5] range ---
# Overall display score in English: 1.1
# Overall display score in Universal: 0.3
# ======================= anshsem =======================
# --- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---
# Cap in English: 0.7287106185584935
# Cap in Universal: 0.2603678379426137
# --- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---
# Overall raw score in English: 0.23
# Overall raw score in Universal: 0.02
# --- Display scores: same as raw scores, but in the [0,5] range ---
# Overall display score in English: 1.2
# Overall display score in Universal: 0.1
# ======================= shradesai =======================
# --- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---
# Cap in English: 0.7668769621923945
# Cap in Universal: 0.5982419966968565
# --- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---
# Overall raw score in English: 0.28
# Overall raw score in Universal: 0.14
# --- Display scores: same as raw scores, but in the [0,5] range ---
# Overall display score in English: 1.4
# Overall display score in Universal: 0.7
# ======================= Phoenix_on_Rise =======================
# --- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---
# Cap in English: 0.4197222421546159
# Cap in Universal: 0.4658392474232361
# --- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---
# Overall raw score in English: 0.08
# Overall raw score in Universal: 0.09
# --- Display scores: same as raw scores, but in the [0,5] range ---
# Overall display score in English: 0.4
# Overall display score in Universal: 0.4
# ======================= sain_me_ =======================
# --- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---
# Cap in English: 0.7967206940193189
# Cap in Universal: 0.805428834471509
# --- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---
# Overall raw score in English: 0.66
# Overall raw score in Universal: 0.52
# --- Display scores: same as raw scores, but in the [0,5] range ---
# Overall display score in English: 3.3
# Overall display score in Universal: 2.6
# ======================= SHIVACINE16 =======================
# --- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---
# Cap in English: 0.7967247202742335
# Cap in Universal: 0.7733457112766196
# --- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---
# Overall raw score in English: 0.6
# Overall raw score in Universal: 0.27
# --- Display scores: same as raw scores, but in the [0,5] range ---
# Overall display score in English: 3.0
# Overall display score in Universal: 1.4
# ======================= sarcasticSoda =======================
# --- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---
# Cap in English: 0.7717813288270262
# Cap in Universal: 0.7219510972984345
# --- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---
# Overall raw score in English: 0.29
# Overall raw score in Universal: 0.21
# --- Display scores: same as raw scores, but in the [0,5] range ---
# Overall display score in English: 1.4
# Overall display score in Universal: 1.0
# ======================= IamSuperEminent =======================
# --- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---
# Cap in English: 0.7961080923981387
# Cap in Universal: 0.7947108099739177
# --- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---
# Overall raw score in English: 0.43
# Overall raw score in Universal: 0.33
# --- Display scores: same as raw scores, but in the [0,5] range ---
# Overall display score in English: 2.2
# Overall display score in Universal: 1.6
# ======================= ThawaniBhushan =======================
# --- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---
# Cap in English: 0.7053377817049258
# Cap in Universal: 0.5742686032713971
# --- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---
# Overall raw score in English: 0.21
# Overall raw score in Universal: 0.13
# --- Display scores: same as raw scores, but in the [0,5] range ---
# Overall display score in English: 1.0
# ...
# --- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---
# Cap in English: 0.7053377817049258
# Cap in Universal: 0.5742686032713971
# --- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---
# Overall raw score in English: 0.21
# Overall raw score in Universal: 0.13
# --- Display scores: same as raw scores, but in the [0,5] range ---
# Overall display score in English: 1.0
# Overall display score in Universal: 0.6
# ======================= sanghi_engineer =======================
# --- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---
# Cap in English: 0.3912159239072283
# Cap in Universal: 0.31739450135566455
# --- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---
# Overall raw score in English: 0.07
# Overall raw score in Universal: 0.04
# --- Display scores: same as raw scores, but in the [0,5] range ---
# Overall display score in English: 0.4
# Overall display score in Universal: 0.2
# ======================= lawmaverick1 =======================
# --- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---
# Cap in English: 0.3912159239072283
# Cap in Universal: 0.40673978557586005
# --- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---
# Overall raw score in English: 0.07
# Overall raw score in Universal: 0.07
# --- Display scores: same as raw scores, but in the [0,5] range ---
# Overall display score in English: 0.4
# Overall display score in Universal: 0.4
# ======================= lawmaverick1 =======================
# --- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---
# Cap in English: 0.3912159239072283
# Cap in Universal: 0.40673978557586005
# --- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---
# Overall raw score in English: 0.07
# Overall raw score in Universal: 0.07
# --- Display scores: same as raw scores, but in the [0,5] range ---
# Overall display score in English: 0.4
# Overall display score in Universal: 0.4
# ======================= omprakash2711 =======================
# --- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---
# Cap in English: 0.7546218700467833
# Cap in Universal: 0.3469210182245441
# --- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---
# Overall raw score in English: 0.26
# Overall raw score in Universal: 0.05
# --- Display scores: same as raw scores, but in the [0,5] range ---
# Overall display score in English: 1.3
# Overall display score in Universal: 0.2
# ======================= an_unknown_wish =======================
# --- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---
# Cap in English: 0.5778862084370772
# Cap in Universal: 0.5488888157824968
# --- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---
# Overall raw score in English: 0.14
# Overall raw score in Universal: 0.12
# --- Display scores: same as raw scores, but in the [0,5] range ---
# Overall display score in English: 0.7
# Overall display score in Universal: 0.6
# ======================= itsflanker =======================
# --- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---
# Cap in English: 0.7470839770895665
# Cap in Universal: 0.5488888157824968
# --- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---
# Overall raw score in English: 0.25
# Overall raw score in Universal: 0.12
# --- Display scores: same as raw scores, but in the [0,5] range ---
# Overall display score in English: 1.2
# Overall display score in Universal: 0.6
# ======================= Nnkk44656557 =======================
# --- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---
# Cap in English: 0.7874002196908744
# Cap in Universal: 0.6945161422354588
# --- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---
# Overall raw score in English: 0.34
# Overall raw score in Universal: 0.19
# --- Display scores: same as raw scores, but in the [0,5] range ---
# Overall display score in English: 1.7
# Overall display score in Universal: 1.0
# ======================= icekoolrahul =======================
# --- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---
# Cap in English: 0.5778862084370772
# Cap in Universal: 0.0
# --- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---
# Overall raw score in English: 0.14
# Overall raw score in Universal: 0.0
# --- Display scores: same as raw scores, but in the [0,5] range ---
# Overall display score in English: 0.7
# Overall display score in Universal: 0.0
# ======================= DipayanDMR =======================
# --- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---
# Cap in English: 0.4197222421546159
# Cap in Universal: 0.28846389695411967
# --- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---
# Overall raw score in English: 0.08
# Overall raw score in Universal: 0.03
# --- Display scores: same as raw scores, but in the [0,5] range ---
# Overall display score in English: 0.4
# Overall display score in Universal: 0.2
# ======================= Evils_Paradise =======================
# --- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---
# Cap in English: 0.621687023966582
# Cap in Universal: 0.7089830786080018
# --- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---
# Overall raw score in English: 0.16
# Overall raw score in Universal: 0.2
# --- Display scores: same as raw scores, but in the [0,5] range ---
# Overall display score in English: 0.8
# Overall display score in Universal: 1.0
# ======================= Bdjena988 =======================
# --- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---
# Cap in English: 0.8036706514015852
# Cap in Universal: 0.8193478253485871
# --- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---
# Overall raw score in English: 0.76
# Overall raw score in Universal: 0.8
# --- Display scores: same as raw scores, but in the [0,5] range ---
# Overall display score in English: 3.8
# Overall display score in Universal: 4.0
# ======================= santuriju =======================
# --- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---
# Cap in English: 0.7952555385005927
# Cap in Universal: 0.3469210182245441
# --- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---
# Overall raw score in English: 0.41
# Overall raw score in Universal: 0.05
# --- Display scores: same as raw scores, but in the [0,5] range ---
# Overall display score in English: 2.0
# Overall display score in Universal: 0.2
# ======================= thejendra =======================
# --- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---
# Cap in English: 0.7470839770895665
# Cap in Universal: 0.8006881983123656
# --- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---
# Overall raw score in English: 0.25
# Overall raw score in Universal: 0.37
# --- Display scores: same as raw scores, but in the [0,5] range ---
# Overall display score in English: 1.2
# Overall display score in Universal: 1.8
# ======================= zab_khan92 =======================
# --- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---
# Cap in English: 0.7287106185584935
# Cap in Universal: 0.5982419966968565
# --- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---
# Overall raw score in English: 0.23
# Overall raw score in Universal: 0.14
# --- Display scores: same as raw scores, but in the [0,5] range ---
# Overall display score in English: 1.2
# Overall display score in Universal: 0.7
# ======================= Aishwaryarbagla =======================
# --- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---
# Cap in English: 0.4479465575931997
# Cap in Universal: 0.28846389695411967
# --- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---
# Overall raw score in English: 0.09
# Overall raw score in Universal: 0.03
# --- Display scores: same as raw scores, but in the [0,5] range ---
# Overall display score in English: 0.4
# Overall display score in Universal: 0.2
# ======================= Sreedha24324771 =======================
# --- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---
# Cap in English: 0.7668769621923945
# Cap in Universal: 0.7733457112766196
# --- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---
# Overall raw score in English: 0.28
# Overall raw score in Universal: 0.27
# --- Display scores: same as raw scores, but in the [0,5] range ---
# Overall display score in English: 1.4
# Overall display score in Universal: 1.4
# ======================= nkagr2706 =======================
# --- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---
# Cap in English: 0.7611878625273879
# Cap in Universal: 0.5222398722127631
# --- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---
# Overall raw score in English: 0.27
# Overall raw score in Universal: 0.11
# --- Display scores: same as raw scores, but in the [0,5] range ---
# Overall display score in English: 1.4
# Overall display score in Universal: 0.6
# ======================= vjv02 =======================
# --- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---
# Cap in English: 0.3342309004634953
# Cap in Universal: 0.37678996390568303
# --- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---
# Overall raw score in English: 0.05
# Overall raw score in Universal: 0.06
# --- Display scores: same as raw scores, but in the [0,5] range ---
# Overall display score in English: 0.2
# Overall display score in Universal: 0.3
# ======================= SamsulH40825884 =======================
# --- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---
# Cap in English: 0.7939576449836836
# Cap in Universal: 0.3469210182245441
# --- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---
# Overall raw score in English: 0.39
# Overall raw score in Universal: 0.05
# --- Display scores: same as raw scores, but in the [0,5] range ---
# Overall display score in English: 2.0
# Overall display score in Universal: 0.2
# ======================= SamsulH40825884 =======================
# --- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---
# Cap in English: 0.7939576449836836
# Cap in Universal: 0.3469210182245441
# --- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---
# Overall raw score in English: 0.39
# Overall raw score in Universal: 0.05
# --- Display scores: same as raw scores, but in the [0,5] range ---
# Overall display score in English: 2.0
# Overall display score in Universal: 0.2
# ======================= KumarPangolin =======================
# --- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---
# Cap in English: 0.6763619064808265
# Cap in Universal: 0.7865642668428161
# --- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---
# Overall raw score in English: 0.19
# Overall raw score in Universal: 0.3
# --- Display scores: same as raw scores, but in the [0,5] range ---
# Overall display score in English: 1.0
# Overall display score in Universal: 1.5
# ======================= hhmollick =======================
# --- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---
# Cap in English: 0.6915799517497913
# Cap in Universal: 0.4658392474232361
# --- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---
# Overall raw score in English: 0.2
# Overall raw score in Universal: 0.09
# --- Display scores: same as raw scores, but in the [0,5] range ---
# Overall display score in English: 1.0
# Overall display score in Universal: 0.4
# ======================= FaridAnsari0786 =======================
# --- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---
# Cap in English: 0.7966668301280437
# Cap in Universal: 0.792436790569533
# --- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---
# Overall raw score in English: 0.61
# Overall raw score in Universal: 0.32
# --- Display scores: same as raw scores, but in the [0,5] range ---
# Overall display score in English: 3.0
# Overall display score in Universal: 1.6
# ======================= FaridAnsari0786 =======================
# --- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---
# Cap in English: 0.7966668301280437
# Cap in Universal: 0.792436790569533
# --- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---
# Overall raw score in English: 0.61
# Overall raw score in Universal: 0.32
# --- Display scores: same as raw scores, but in the [0,5] range ---
# Overall display score in English: 3.0
# Overall display score in Universal: 1.6
# ======================= bitmasti =======================
# --- Cap:  Conditional probability that accounts with a score equal to or greater than this are automated (based on inferred language)---
# Cap in English: 0.793087009461318
# Cap in Universal: 0.8035432096295109
# --- Raw scores: bot score in the [0,1] range, both using English (all features) and Universal (language-independent) features ---
# Overall raw score in English: 0.38
# Overall raw score in Universal: 0.41
# --- Display scores: same as raw scores, but in the [0,5] range ---
# Overall display score in English: 1.9
# Overall display score in Universal: 2.0

# %% [markdown]
# ### Append the Botometer scores and save the dataframe

# %% [markdown]
# Append the Botometer scores to the original pandas dataframe

# %%
df ['botometerCapEng.score'] = cap_english_list
df ['botometerCapUni.score'] = cap_universal_list
df ['botometerOverallRawEng.score'] = overall_raw_score_eng_list
df ['botometerOverallRawUni.score'] = overall_raw_score_universal_list
df ['botometerDisplayEng.score'] = overall_display_score_eng_list
df ['botometerDisplayUni.score'] = overall_display_score_universal_list

# %% [markdown]
# Save the dataframe with appended Botometer scores as CSV

# %%
#df.to_csv('/content/drive/MyDrive/replies-alviinaalametsa-annotated-botometer.csv', index=False)
df.to_csv('/content/drive/MyDrive/replies-larrouturou-annotated-botometer.csv', index=False)
